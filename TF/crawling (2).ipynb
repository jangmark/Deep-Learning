# %% [markdown]
# # [1] 카카오 크롤링

# %% [markdown]
# ### [1-1] 카카오 url 수집

# %%
import pandas as pd
import matplotlib.pyplot as plt
from selenium import webdriver #pip install selenium
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import re
import time
import selenium
from selenium.webdriver.common.action_chains import ActionChains
selenium.__version__ 
def collect_kakaomap_url(text):
    path = 'C:/chromedriver_win32/chromedriver.exe'
    source_url = "https://map.kakao.com/"
    driver = webdriver.Chrome(path)
    driver.get(source_url)
    # id="search.keyword.query" 태그 선택=> input 태그 
    searchbox=driver.find_element(By.ID,"search.keyword.query") 
    searchbox.send_keys(text) #url 수집을 원하는 값 입력
    # id="search.keyword.submit" 태그 선택=> input 태그 
    searchbutton=driver.find_element(By.ID,"search.keyword.submit") 
    #script를 실행
    #arguments[0].click(); : 첫번째 매개변수값을 클릭
    driver.execute_script("arguments[0].click();", searchbutton) #검색버튼클릭.
    time.sleep(2) #2초동안 대기 =>  검색 결과가 브라우저에 표시됨
    html = driver.page_source # 현재브라우저의 소스(html)
    soup = BeautifulSoup(html, "html.parser") # BeautifulSoup 분석
    # name="a": a태그
    # attrs={"class":"moreview" : a태그중에 class속성이 moreview인 태그
    moreviews = soup.find_all(name="a", attrs={"class":"moreview"}) # 상세보기들
    page_urls = [] 
    for moreview in moreviews:
        # moreview: 한개의 상세보기. a태그
        page_url = moreview.get("href") # a태그의 href 속성의 값
        page_urls.append(page_url) #상세보기의 href 속성값들 목록. 식당 URL 목록
    # driver.close()    
    more_place = driver.find_element(By.ID,'info.search.place.more')
    actions = ActionChains(driver )#스크롤내리기
    actions.move_to_element(more_place).perform()
    time.sleep(1)
    layer_button = driver.find_element_by_css_selector('body > div.coach_layer.coach_layer_type1 > div > div > div > span')
    layer_button.click()
    

    time.sleep(1)
    more_place.click()
    try:
        more_place.click()
    except:
        more_place = driver.find_element_by_xpath('/html/body/div[5]/div[2]/div[1]/div[7]/div[5]/a')
        more_place.click()
    page_num = 3
    while True:
        time.sleep(1.5)
        html = driver.page_source # 현재브라우저의 소스(html)
        soup = BeautifulSoup(html, "html.parser") # BeautifulSoup 분석
        # name="a": a태그
        # attrs={"class":"moreview" : a태그중에 class속성이 moreview인 태그
        moreviews = soup.find_all(name="a", attrs={"class":"moreview"}) # 상세보기들
        
        for moreview in moreviews:
            # moreview: 한개의 상세보기. a태그
            page_url = moreview.get("href") # a태그의 href 속성의 값
            page_urls.append(page_url) #상세보기의 href 속성값들 목록. 강남역 고기집의 URL 정보 목록
        try:# 페이지 버튼마다 반복 없을 시 다음 페이지로 선택
            page_button = driver.find_element_by_css_selector('#info\.search\.page\.no{}'.format(page_num))
            page_num += 1
        except Exception:
            page_button = driver.find_element_by_css_selector('#info\.search\.page\.next')
            page_num = 2
            
        try:#버튼 클릭 및 요소가 없을 시 break
            page_button.click()
        except:
            break
    return page_urls

# %%
page_urls = collect_kakaomap_url('복현동 맛집')

# %%
page_urls
# Out:
# ['https://place.map.kakao.com/10332413',
#  'https://place.map.kakao.com/853028118',
#  'https://place.map.kakao.com/1974266862',
#  'https://place.map.kakao.com/1065693087',
#  'https://place.map.kakao.com/27584230',
#  'https://place.map.kakao.com/348276052',
#  'https://place.map.kakao.com/27531028',
#  'https://place.map.kakao.com/13559837',
#  'https://place.map.kakao.com/1492599844',
#  'https://place.map.kakao.com/220597413',
#  'https://place.map.kakao.com/27540102',
#  'https://place.map.kakao.com/1677426767',
#  'https://place.map.kakao.com/211389635',
#  'https://place.map.kakao.com/10785496',
#  'https://place.map.kakao.com/1950123074',
#  'https://place.map.kakao.com/8025375',
#  'https://place.map.kakao.com/2029456983',
#  'https://place.map.kakao.com/21359554',
#  'https://place.map.kakao.com/1301973155',
#  'https://place.map.kakao.com/444516464',
#  'https://place.map.kakao.com/745164647',
#  'https://place.map.kakao.com/87323834',
#  'https://place.map.kakao.com/7851288',
#  'https://place.map.kakao.com/1803090740',
#  'https://place.map.kakao.com/179244712',
#  'https://place.map.kakao.com/21555096',
#  'https://place.map.kakao.com/10587024',
#  'https://place.map.kakao.com/907979960',
#  'https://place.map.kakao.com/13289056',
#  'https://place.map.kakao.com/12706932',
#  'https://place.map.kakao.com/1807739168',
#  'https://place.map.kakao.com/353512935',
#  'https://place.map.kakao.com/447132083',
#  'https://place.map.kakao.com/8552691',
#  'https://place.map.kakao.com/898970657',
#  'https://place.map.kakao.com/21852953',
#  'https://place.map.kakao.com/1779571274',
#  'https://place.map.kakao.com/1317959049',
#  'https://place.map.kakao.com/25036918',
#  'https://place.map.kakao.com/24725293',
#  'https://place.map.kakao.com/1480354584',
#  'https://place.map.kakao.com/34237220',
#  'https://place.map.kakao.com/25048467',
#  'https://place.map.kakao.com/25046575',
#  'https://place.map.kakao.com/670102239',
#  'https://place.map.kakao.com/1863534623',
#  'https://place.map.kakao.com/15982071',
#  'https://place.map.kakao.com/2032952073',
#  'https://place.map.kakao.com/21326655',
#  'https://place.map.kakao.com/802213706',
#  'https://place.map.kakao.com/378913911',
#  'https://place.map.kakao.com/1124684582',
#  'https://place.map.kakao.com/8746906',
#  'https://place.map.kakao.com/1238400864',
#  'https://place.map.kakao.com/26545925',
#  'https://place.map.kakao.com/11190567',
#  'https://place.map.kakao.com/26235884',
#  'https://place.map.kakao.com/24529429',
#  'https://place.map.kakao.com/8332362',
#  'https://place.map.kakao.com/1770731230',
#  'https://place.map.kakao.com/1228257268',
#  'https://place.map.kakao.com/7904353',
#  'https://place.map.kakao.com/34321780',
#  'https://place.map.kakao.com/558503389',
#  'https://place.map.kakao.com/25479306',
#  'https://place.map.kakao.com/12048202',
#  'https://place.map.kakao.com/145791269',
#  'https://place.map.kakao.com/27175293',
#  'https://place.map.kakao.com/1228208521',
#  'https://place.map.kakao.com/17163273',
#  'https://place.map.kakao.com/16990385',
#  'https://place.map.kakao.com/13093208',
#  'https://place.map.kakao.com/1318722307',
#  'https://place.map.kakao.com/1783691580',
#  'https://place.map.kakao.com/8758064',
#  'https://place.map.kakao.com/14615423',
#  'https://place.map.kakao.com/1951923315',
#  'https://place.map.kakao.com/19158798',
#  'https://place.map.kakao.com/25038356',
#  'https://place.map.kakao.com/711864705',
#  'https://place.map.kakao.com/11642405',
#  'https://place.map.kakao.com/1449183784',
#  'https://place.map.kakao.com/7885551',
#  'https://place.map.kakao.com/469577034',
#  'https://place.map.kakao.com/27209120',
#  'https://place.map.kakao.com/260283466',
#  'https://place.map.kakao.com/8279464',
#  'https://place.map.kakao.com/26930532',
#  'https://place.map.kakao.com/19880897',
#  'https://place.map.kakao.com/983993205',
#  'https://place.map.kakao.com/16734831',
#  'https://place.map.kakao.com/1165755646',
#  'https://place.map.kakao.com/27072121',
#  'https://place.map.kakao.com/26572124',
#  'https://place.map.kakao.com/1965582130',
#  'https://place.map.kakao.com/495658881',
#  'https://place.map.kakao.com/1619274444',
#  'https://place.map.kakao.com/26971014',
#  'https://place.map.kakao.com/22549791',
#  'https://place.map.kakao.com/16421356',
#  'https://place.map.kakao.com/15580829',
#  'https://place.map.kakao.com/1337569618',
#  'https://place.map.kakao.com/1822111964',
#  'https://place.map.kakao.com/8094563',
#  'https://place.map.kakao.com/10546066',
#  'https://place.map.kakao.com/25049102',
#  'https://place.map.kakao.com/2092039626',
#  'https://place.map.kakao.com/18536783',
#  'https://place.map.kakao.com/19351143',
#  'https://place.map.kakao.com/23699720',
#  'https://place.map.kakao.com/7919722',
#  'https://place.map.kakao.com/2067124772',
#  'https://place.map.kakao.com/630064388',
#  'https://place.map.kakao.com/11231325',
#  'https://place.map.kakao.com/702337989',
#  'https://place.map.kakao.com/1916682638',
#  'https://place.map.kakao.com/18279130',
#  'https://place.map.kakao.com/196078294',
#  'https://place.map.kakao.com/20747449',
#  'https://place.map.kakao.com/20709046',
#  'https://place.map.kakao.com/16330571',
#  'https://place.map.kakao.com/19452961',
#  'https://place.map.kakao.com/19156993',
#  'https://place.map.kakao.com/1235425275',
#  'https://place.map.kakao.com/1346301870',
#  'https://place.map.kakao.com/243733683',
#  'https://place.map.kakao.com/18569567',
#  'https://place.map.kakao.com/554364299',
#  'https://place.map.kakao.com/967729291',
#  'https://place.map.kakao.com/22837049',
#  'https://place.map.kakao.com/1087043762',
#  'https://place.map.kakao.com/1386489124',
#  'https://place.map.kakao.com/10122642',
#  'https://place.map.kakao.com/10889757',
#  'https://place.map.kakao.com/27269085',
#  'https://place.map.kakao.com/2053098478',
#  'https://place.map.kakao.com/1511737742',
#  'https://place.map.kakao.com/15526158',
#  'https://place.map.kakao.com/13561654',
#  'https://place.map.kakao.com/9012776',
#  'https://place.map.kakao.com/1201642510',
#  'https://place.map.kakao.com/8174854',
#  'https://place.map.kakao.com/339122660',
#  'https://place.map.kakao.com/16414503',
#  'https://place.map.kakao.com/1010045527',
#  'https://place.map.kakao.com/1393296142',
#  'https://place.map.kakao.com/25891059',
#  'https://place.map.kakao.com/8144397',
#  'https://place.map.kakao.com/27306859',
#  'https://place.map.kakao.com/610799971',
#  'https://place.map.kakao.com/1372079546',
#  'https://place.map.kakao.com/12435058',
#  'https://place.map.kakao.com/8218085',
#  'https://place.map.kakao.com/1967338071',
#  'https://place.map.kakao.com/8364935',
#  'https://place.map.kakao.com/1752978029',
#  'https://place.map.kakao.com/18755777',
#  'https://place.map.kakao.com/8416853',
#  'https://place.map.kakao.com/1429224581',
#  'https://place.map.kakao.com/1312159706',
#  'https://place.map.kakao.com/25744174',
#  'https://place.map.kakao.com/12140312',
#  'https://place.map.kakao.com/66544493',
#  'https://place.map.kakao.com/9370927',
#  'https://place.map.kakao.com/25770215',
#  'https://place.map.kakao.com/83301316',
#  'https://place.map.kakao.com/929624344',
#  'https://place.map.kakao.com/27508076',
#  'https://place.map.kakao.com/429895682',
#  'https://place.map.kakao.com/24448306',
#  'https://place.map.kakao.com/8203240',
#  'https://place.map.kakao.com/18076495',
#  'https://place.map.kakao.com/7818113',
#  'https://place.map.kakao.com/27454501',
#  'https://place.map.kakao.com/2017667910',
#  'https://place.map.kakao.com/26410902',
#  'https://place.map.kakao.com/8008344',
#  'https://place.map.kakao.com/1737612851',
#  'https://place.map.kakao.com/26576095',
#  'https://place.map.kakao.com/24065719',
#  'https://place.map.kakao.com/1622865435',
#  'https://place.map.kakao.com/22906526',
#  'https://place.map.kakao.com/856589054',
#  'https://place.map.kakao.com/26973107',
#  'https://place.map.kakao.com/8055849',
#  'https://place.map.kakao.com/21212902',
#  'https://place.map.kakao.com/8079539',
#  'https://place.map.kakao.com/8397790',
#  'https://place.map.kakao.com/12747379',
#  'https://place.map.kakao.com/10651104',
#  'https://place.map.kakao.com/95713992',
#  'https://place.map.kakao.com/1954563179',
#  'https://place.map.kakao.com/7873176',
#  'https://place.map.kakao.com/8050105',
#  'https://place.map.kakao.com/15937430',
#  'https://place.map.kakao.com/21423297',
#  'https://place.map.kakao.com/1376253571',
#  'https://place.map.kakao.com/16649162',
#  'https://place.map.kakao.com/892514586',
#  'https://place.map.kakao.com/8381402',
#  'https://place.map.kakao.com/10331494',
#  'https://place.map.kakao.com/872257394',
#  'https://place.map.kakao.com/1821978316',
#  'https://place.map.kakao.com/21232315',
#  'https://place.map.kakao.com/27261403',
#  'https://place.map.kakao.com/26792732',
#  'https://place.map.kakao.com/561633351',
#  'https://place.map.kakao.com/1508329235',
#  'https://place.map.kakao.com/13337591',
#  'https://place.map.kakao.com/2143988257',
#  'https://place.map.kakao.com/8476706',
#  'https://place.map.kakao.com/7937472',
#  'https://place.map.kakao.com/9125675',
#  'https://place.map.kakao.com/15317417',
#  'https://place.map.kakao.com/26567082',
#  'https://place.map.kakao.com/16732242',
#  'https://place.map.kakao.com/8082652',
#  'https://place.map.kakao.com/487116221',
#  'https://place.map.kakao.com/1709558766',
#  'https://place.map.kakao.com/8219772',
#  'https://place.map.kakao.com/11152625',
#  'https://place.map.kakao.com/9475630',
#  'https://place.map.kakao.com/11356521',
#  'https://place.map.kakao.com/7908112',
#  'https://place.map.kakao.com/142439579',
#  'https://place.map.kakao.com/1503746075',
#  'https://place.map.kakao.com/12695795',
#  'https://place.map.kakao.com/26939037',
#  'https://place.map.kakao.com/1860681564',
#  'https://place.map.kakao.com/7963415',
#  'https://place.map.kakao.com/1428481536',
#  'https://place.map.kakao.com/294491415',
#  'https://place.map.kakao.com/12055448',
#  'https://place.map.kakao.com/8153541',
#  'https://place.map.kakao.com/27512695',
#  'https://place.map.kakao.com/25036974',
#  'https://place.map.kakao.com/13319252',
#  'https://place.map.kakao.com/1458885971',
#  'https://place.map.kakao.com/828640256',
#  'https://place.map.kakao.com/26967162',
#  'https://place.map.kakao.com/27187492',
#  'https://place.map.kakao.com/1546656402',
#  'https://place.map.kakao.com/283930207',
#  'https://place.map.kakao.com/1226420399',
#  'https://place.map.kakao.com/18363906',
#  'https://place.map.kakao.com/2011092566',
#  'https://place.map.kakao.com/13575898',
#  'https://place.map.kakao.com/673846395',
#  'https://place.map.kakao.com/7815078',
#  'https://place.map.kakao.com/1797970569',
#  'https://place.map.kakao.com/7819490',
#  'https://place.map.kakao.com/7891904',
#  'https://place.map.kakao.com/10582837',
#  'https://place.map.kakao.com/7983060',
#  'https://place.map.kakao.com/27321311',
#  'https://place.map.kakao.com/253560122',
#  'https://place.map.kakao.com/378458912',
#  'https://place.map.kakao.com/1540882128',
#  'https://place.map.kakao.com/168079537',
#  'https://place.map.kakao.com/2069090006',
#  'https://place.map.kakao.com/27276847',
#  'https://place.map.kakao.com/24725284',
#  'https://place.map.kakao.com/27564595',
#  'https://place.map.kakao.com/7912367',
#  'https://place.map.kakao.com/13092552',
#  'https://place.map.kakao.com/1179567185',
#  'https://place.map.kakao.com/1769574951',
#  'https://place.map.kakao.com/22016385',
#  'https://place.map.kakao.com/53292857',
#  'https://place.map.kakao.com/18310200',
#  'https://place.map.kakao.com/12106466',
#  'https://place.map.kakao.com/22716674',
#  'https://place.map.kakao.com/1539453182',
#  'https://place.map.kakao.com/16447083',
#  'https://place.map.kakao.com/7855455',
#  'https://place.map.kakao.com/18597642',
#  'https://place.map.kakao.com/16380488',
#  'https://place.map.kakao.com/1367229148',
#  'https://place.map.kakao.com/8078768',
#  'https://place.map.kakao.com/27353169',
#  'https://place.map.kakao.com/21535686',
#  'https://place.map.kakao.com/1087614547',
#  'https://place.map.kakao.com/266428861',
#  'https://place.map.kakao.com/21732408',
#  'https://place.map.kakao.com/7997827',
#  'https://place.map.kakao.com/20526340',
#  'https://place.map.kakao.com/741391811',
#  'https://place.map.kakao.com/16937330',
#  'https://place.map.kakao.com/8005800',
#  'https://place.map.kakao.com/219797863',
#  'https://place.map.kakao.com/11486129',
#  'https://place.map.kakao.com/1062153333',
#  'https://place.map.kakao.com/7872029',
#  'https://place.map.kakao.com/1877651691',
#  'https://place.map.kakao.com/1440347564',
#  'https://place.map.kakao.com/1054118175',
#  'https://place.map.kakao.com/21299769',
#  'https://place.map.kakao.com/152172304',
#  'https://place.map.kakao.com/11064200',
#  'https://place.map.kakao.com/2039301214',
#  'https://place.map.kakao.com/162078159',
#  'https://place.map.kakao.com/934767425',
#  'https://place.map.kakao.com/8051186',
#  'https://place.map.kakao.com/2032190005',
#  'https://place.map.kakao.com/502958473',
#  'https://place.map.kakao.com/7981207',
#  'https://place.map.kakao.com/10731091',
#  'https://place.map.kakao.com/26485620',
#  'https://place.map.kakao.com/218867054',
#  'https://place.map.kakao.com/1808171777',
#  'https://place.map.kakao.com/27504403',
#  'https://place.map.kakao.com/185267351',
#  'https://place.map.kakao.com/27226419',
#  'https://place.map.kakao.com/17781427',
#  'https://place.map.kakao.com/8475048',
#  'https://place.map.kakao.com/8097973',
#  'https://place.map.kakao.com/2111300834',
#  'https://place.map.kakao.com/8176347',
#  'https://place.map.kakao.com/12751485',
#  'https://place.map.kakao.com/25770378',
#  'https://place.map.kakao.com/10311622',
#  'https://place.map.kakao.com/8258626',
#  'https://place.map.kakao.com/1052874675',
#  'https://place.map.kakao.com/19157171',
#  'https://place.map.kakao.com/565792969',
#  'https://place.map.kakao.com/850873071',
#  'https://place.map.kakao.com/8086138',
#  'https://place.map.kakao.com/2080551677',
#  'https://place.map.kakao.com/8140834',
#  'https://place.map.kakao.com/8082703',
#  'https://place.map.kakao.com/10344284',
#  'https://place.map.kakao.com/1545245527',
#  'https://place.map.kakao.com/19032013',
#  'https://place.map.kakao.com/1574612084',
#  'https://place.map.kakao.com/96877138',
#  'https://place.map.kakao.com/15431872',
#  'https://place.map.kakao.com/603985516',
#  'https://place.map.kakao.com/1128989913',
#  'https://place.map.kakao.com/12265333',
#  'https://place.map.kakao.com/12004662',
#  'https://place.map.kakao.com/13491393',
#  'https://place.map.kakao.com/1658512250',
#  'https://place.map.kakao.com/965893653',
#  'https://place.map.kakao.com/220828644',
#  'https://place.map.kakao.com/27373628',
#  'https://place.map.kakao.com/20746242',
#  'https://place.map.kakao.com/109169564',
#  'https://place.map.kakao.com/861945610',
#  'https://place.map.kakao.com/614661957',
#  'https://place.map.kakao.com/335111559',
#  'https://place.map.kakao.com/23985599',
#  'https://place.map.kakao.com/1248615345',
#  'https://place.map.kakao.com/21360176',
#  'https://place.map.kakao.com/1198183678',
#  'https://place.map.kakao.com/16624169',
#  'https://place.map.kakao.com/8021209',
#  'https://place.map.kakao.com/12098170',
#  'https://place.map.kakao.com/15958681',
#  'https://place.map.kakao.com/8449040',
#  'https://place.map.kakao.com/15892869',
#  'https://place.map.kakao.com/14532428',
#  'https://place.map.kakao.com/1851273390',
#  'https://place.map.kakao.com/629672914',
#  'https://place.map.kakao.com/11221819',
#  'https://place.map.kakao.com/12990437',
#  'https://place.map.kakao.com/1345866783',
#  'https://place.map.kakao.com/1943025765',
#  'https://place.map.kakao.com/14951761',
#  'https://place.map.kakao.com/26858784',
#  'https://place.map.kakao.com/8510748',
#  'https://place.map.kakao.com/1155031193',
#  'https://place.map.kakao.com/858715549',
#  'https://place.map.kakao.com/21445025',
#  'https://place.map.kakao.com/1214126801',
#  'https://place.map.kakao.com/1937691860',
#  'https://place.map.kakao.com/13102233',
#  'https://place.map.kakao.com/11831509',
#  'https://place.map.kakao.com/18685434',
#  'https://place.map.kakao.com/1465968863',
#  'https://place.map.kakao.com/17662981',
#  'https://place.map.kakao.com/1026281815',
#  'https://place.map.kakao.com/7865809',
#  'https://place.map.kakao.com/27280337',
#  'https://place.map.kakao.com/12793877',
#  'https://place.map.kakao.com/7990640',
#  'https://place.map.kakao.com/1407082787',
#  'https://place.map.kakao.com/9141738',
#  'https://place.map.kakao.com/657926243',
#  'https://place.map.kakao.com/8106735',
#  'https://place.map.kakao.com/20745677',
#  'https://place.map.kakao.com/8041476',
#  'https://place.map.kakao.com/647318999',
#  'https://place.map.kakao.com/8143287',
#  'https://place.map.kakao.com/2097885929',
#  'https://place.map.kakao.com/8505372',
#  'https://place.map.kakao.com/1952478679',
#  'https://place.map.kakao.com/445165609',
#  'https://place.map.kakao.com/16037952',
#  'https://place.map.kakao.com/604720323',
#  'https://place.map.kakao.com/2005375589',
#  'https://place.map.kakao.com/27477443',
#  'https://place.map.kakao.com/8313639',
#  'https://place.map.kakao.com/2108354197',
#  'https://place.map.kakao.com/15204021',
#  'https://place.map.kakao.com/26345855',
#  'https://place.map.kakao.com/1985225055',
#  'https://place.map.kakao.com/23523555',
#  'https://place.map.kakao.com/1591202287',
#  'https://place.map.kakao.com/8416287',
#  'https://place.map.kakao.com/26550666',
#  'https://place.map.kakao.com/9921124',
#  'https://place.map.kakao.com/11833906',
#  'https://place.map.kakao.com/15965312',
#  'https://place.map.kakao.com/27248381',
#  'https://place.map.kakao.com/26971510',
#  'https://place.map.kakao.com/8323721',
#  'https://place.map.kakao.com/1755515956',
#  'https://place.map.kakao.com/25155819',
#  'https://place.map.kakao.com/11418974',
#  'https://place.map.kakao.com/18489028',
#  'https://place.map.kakao.com/1315266972',
#  'https://place.map.kakao.com/13582855',
#  'https://place.map.kakao.com/9199444',
#  'https://place.map.kakao.com/10668060',
#  'https://place.map.kakao.com/8228599',
#  'https://place.map.kakao.com/922091993',
#  'https://place.map.kakao.com/14569639',
#  'https://place.map.kakao.com/1513265709',
#  'https://place.map.kakao.com/8107623',
#  'https://place.map.kakao.com/8098721',
#  'https://place.map.kakao.com/24371711',
#  'https://place.map.kakao.com/27221935',
#  'https://place.map.kakao.com/1154772851',
#  'https://place.map.kakao.com/143245596',
#  'https://place.map.kakao.com/27280302',
#  'https://place.map.kakao.com/26199786',
#  'https://place.map.kakao.com/8038298',
#  'https://place.map.kakao.com/10199904',
#  'https://place.map.kakao.com/10972091',
#  'https://place.map.kakao.com/1099251112',
#  'https://place.map.kakao.com/26455895',
#  'https://place.map.kakao.com/1958239830',
#  'https://place.map.kakao.com/8002833',
#  'https://place.map.kakao.com/8664636',
#  'https://place.map.kakao.com/1407569042',
#  'https://place.map.kakao.com/14701954',
#  'https://place.map.kakao.com/8568141',
#  'https://place.map.kakao.com/1646052453',
#  'https://place.map.kakao.com/16983115',
#  'https://place.map.kakao.com/11914726',
#  'https://place.map.kakao.com/497931179',
#  'https://place.map.kakao.com/20553565',
#  'https://place.map.kakao.com/11781456',
#  'https://place.map.kakao.com/27352120',
#  'https://place.map.kakao.com/1784717740',
#  'https://place.map.kakao.com/291477942',
#  'https://place.map.kakao.com/1130537615',
#  'https://place.map.kakao.com/770095922',
#  'https://place.map.kakao.com/1641347883',
#  'https://place.map.kakao.com/27506479',
#  'https://place.map.kakao.com/308342289',
#  'https://place.map.kakao.com/12444560',
#  'https://place.map.kakao.com/27238067',
#  'https://place.map.kakao.com/768850911',
#  'https://place.map.kakao.com/27315574',
#  'https://place.map.kakao.com/256064588',
#  'https://place.map.kakao.com/1319161148',
#  'https://place.map.kakao.com/21306153',
#  'https://place.map.kakao.com/138978252',
#  'https://place.map.kakao.com/27311545',
#  'https://place.map.kakao.com/18582704',
#  'https://place.map.kakao.com/2034797687',
#  'https://place.map.kakao.com/21827385',
#  'https://place.map.kakao.com/9427365',
#  'https://place.map.kakao.com/791775664',
#  'https://place.map.kakao.com/7891890',
#  'https://place.map.kakao.com/1511775558',
#  'https://place.map.kakao.com/15659043',
#  'https://place.map.kakao.com/8163082',
#  'https://place.map.kakao.com/971121714',
#  'https://place.map.kakao.com/11043215',
#  'https://place.map.kakao.com/27300932',
#  'https://place.map.kakao.com/12418029',
#  'https://place.map.kakao.com/22961938',
#  'https://place.map.kakao.com/1153635092',
#  'https://place.map.kakao.com/1797997961',
#  'https://place.map.kakao.com/10635098',
#  'https://place.map.kakao.com/400281849',
#  'https://place.map.kakao.com/11891906',
#  'https://place.map.kakao.com/286483883',
#  'https://place.map.kakao.com/256884650',
#  'https://place.map.kakao.com/16090577',
#  'https://place.map.kakao.com/1493852185',
#  'https://place.map.kakao.com/16044160',
#  'https://place.map.kakao.com/90725902',
#  'https://place.map.kakao.com/16852004',
#  'https://place.map.kakao.com/27248379',
#  'https://place.map.kakao.com/7939102',
#  'https://place.map.kakao.com/27584176',
#  'https://place.map.kakao.com/11162975']

# %%
len(page_urls)
# Out:
# 500

# %% [markdown]
# ---
# ### [1-2] URL 1개에 대한 df생성
# ### TEST용 실제 실행하지 않아도 됨
# ---

# %%
# 상세보기에 조회된 고기집 목록을 조회
path = 'C:/chromedriver_win32/chromedriver.exe'
df = pd.DataFrame() # 컬럼만 조회
driver = webdriver.Chrome(path) # 브라우저 실행
# for page in page_urls:
df = pd.DataFrame()
time.sleep(1)
# for page in page_urls:
driver.get(page_urls[0]) # 식당 데이터 상세화면
time.sleep(2) # 2초 쉬기
html = driver.page_source # html 소스 데이터 (page 소스를 html에 세팅)
soup = BeautifulSoup(html, 'html.parser')


total_strong = soup.find(name="strong", attrs={"class": "total_evaluation"})
try:
    tot_num = total_strong.find(name="span", attrs={"class": "color_b"}) # 등록된 리뷰 갯수
except:
    pass
# continue
if (int(tot_num.text)-3)%5 == 0:  
    more_text_num= ((int(tot_num.text)-3)//5)
else:
    more_text_num= ((int(tot_num.text)-3)//5)+1

if more_text_num == 0:
    pass
else:
    try:
        for i in range(more_text_num):
            more_text_in_store = driver.find_element_by_css_selector('span.txt_more')  
            actions = ActionChains(driver)#스크롤내리기
            actions.move_to_element(more_text_in_store).perform()
            more_text_in_store.click()
            time.sleep(0.5)
    except:
        pass
        
rate_list =[]
review_list =[]

html = driver.page_source # html 소스 데이터 (page 소스를 html에 세팅)
soup = BeautifulSoup(html, 'html.parser')
try:        
    store_name = soup.find(name = 'h2', attrs = {'class':'tit_location'})#가게이름
    addr = soup.find(name = 'span', attrs = {'class':'txt_address'})#가게주소
    store_operate_day = soup.find(name = 'span', attrs = {'class':'txt_operation'})#영업일 및 영업시간
    menu = soup.find_all(name = 'span', attrs = {'class':'loss_word'})
    
    img_urls = soup.find(name='span', attrs={'class':'bg_present'})
    img_urls = img_urls.get('style')
    start_idx = img_urls.find('url(') + 4  # "url(" 다음 인덱스부터 시작
    end_idx = img_urls.find(')', start_idx)
    url = img_urls[start_idx:end_idx]
    

    total_strong = soup.find(name="strong", attrs={"class": "total_evaluation"})
    tot_num = total_strong.find(name="span", attrs={"class": "color_b"}) # 등록된 리뷰 갯수
    contents_div = soup.find(name='div', attrs={"class": "evaluation_review"}) #리뷰 영역. 별점, 내용
    reviewer_average_score = contents_div.find_all(name="span", attrs={"class": "txt_desc"})#리뷰어의 평균평점
    #reviewer_num = soup.find(name="span", attrs={"class": "text_desc"})#리뷰어의 평균평점
    rates=contents_div.find_all(name="span", attrs={"class": "ico_star star_rate"}) # 별점값 목록
    reviews = contents_div.find_all(name="p", attrs={"class": "txt_comment"}) # 리뷰 목록
except:
    pass
    #continue
    # try 구문에서 오류 발생된 경우 다음 페이지로 이동 
#     # 리뷰의 1페이지 정보를 df에 저장
menu_list = []
rate_list =[]
review_list =[]
reviewer_average_score_list = []
reviewer_num_list = []

# for i in range(reviewer_average_score):
#     reviewer_average_score_list.append(reviewer_average_score)
    
for i in range(len(rates)):
    rate_value = rates[i].find(name='span', attrs={"class": "ico_star"})
    style_value = rate_value.get('style')
    if style_value == 'width:20%;':
        rate = 1
    elif style_value == 'width:40%;':
        rate = 2
    elif style_value == 'width:60%;':
        rate = 3
    elif style_value == 'width:80%;':
        rate = 4
    elif style_value == 'width:100%;':
        rate = 5
    rate_list.append(rate)    
for review in reviews:
    rev_span = review.find(name="span")
    if rev_span is not None and rev_span.text:
        rev = rev_span.text
    else:
        rev = ''
    review_list.append(rev)
for i in range(len(reviewer_average_score)):
    if i%2 == 0:
        reviewer_average_score_list.append(reviewer_average_score[i].text)
    else:
        reviewer_num_list.append(reviewer_average_score[i].text)
menu_str = ''
if len(menu)>0:
    for i in menu:
        menu_str += i.text + ' '
    menu_list = menu_str.rstrip()
else:
    menu_list = ''       


store_name = store_name.text
try: 
    addr = addr.text
    addr = [i.strip() for i in addr.split('\n')]
    addr = ' '.join(addr)
except:
    addr = ''
try:
    store_operate_day = store_operate_day.text
    store_operate_day = store_operate_day.replace('\n', '')
except:
    store_operate_day = ''
#이미지 url 추가하기


df['리뷰'] = review_list
df['별점'] = rate_list
df['리뷰자 평균 평점'] = reviewer_average_score_list
df['리뷰자 누적 리뷰 개수'] = reviewer_num_list
df['영업 시간'] = store_operate_day
df['이미지url'] = url
df['가게명'] = store_name
df['가게 주소'] = addr
df['메뉴'] = menu_list
df.shape
# Out:
# (16, 9)

# %%
df
# Out:
#                                                    리뷰  별점 리뷰자 평균 평점  \
# 0                                   성발라가 오히려 망친 것인가..   1       501
# 1   조용할 시간에 가서 너무 맛있게 편하게 먹었습니다. 서비스에 대해선 호불호가 있을 ...   5         5
# 2   왠만하면리뷰안쓰는데 최악중에최악 정말최악사장님이글보면 저아시겠죠? 서비스는바라지도않...   1         1
# 3   생고기 소자 주문하려니  양이 적다고  중자주문 유도한다 둘이 왔는데  중짜? 얼마...   1        22
# 4   성시경이 띄워놓았지만 대구에는 이것보다 훨씬 가성비 좋고 맛있는 생고기 집이 많다 ...   2        41
# 5   가지마세요 식당 지저분함. 기본안주 더 달라고 해도 '주문이 밀려서요'라고 말하면서...   1        12
# 6   밑반찬이 많아서 좋았고 맛도 좋았습니다. 뭉티기도 처음 먹어보는데 쫄깃하고 회먹는 ...   4         7
# 7                                            생고기 끝내줘요   5        25
# 8   유튜브에 속은 기분. 생고기는 무난하나 굳이 이 가격에 이 웨이팅에? 먹을 정도는 ...   2         4
# 9   생고기가 먼저 나오고 밑반찬이 세팅됩니다. 생고기 대자는 생각보다 양이 많지 않습니...   5        74
# 10                                               별로예요   1         9
# 11                                       덤탱이 썼어요,, 흑흑   1         6
# 12  생고기 생각날 때마다 꼭 가는 곳입니다ㅎㅎ예전엔 현지인 단골 분들이 많이 오시는 분...   5         1
# 13                 고기는 좋은편이나밑반찬이나가격대비하면 추천할만 하지는 않습니다   3         4
# 14                                                      2         2
# 15                                                      5         1
#
#    리뷰자 누적 리뷰 개수             영업 시간  \
# 0           3.8  매일 17:00 ~ 24:00
# 1           3.4  매일 17:00 ~ 24:00
# 2           1.0  매일 17:00 ~ 24:00
# 3           3.5  매일 17:00 ~ 24:00
# 4           3.2  매일 17:00 ~ 24:00
# 5           4.7  매일 17:00 ~ 24:00
# 6           3.7  매일 17:00 ~ 24:00
# 7           3.8  매일 17:00 ~ 24:00
# 8           3.3  매일 17:00 ~ 24:00
# 9           3.1  매일 17:00 ~ 24:00
# 10          3.3  매일 17:00 ~ 24:00
# 11          3.2  매일 17:00 ~ 24:00
# 12          5.0  매일 17:00 ~ 24:00
# 13          2.5  매일 17:00 ~ 24:00
# 14          2.0  매일 17:00 ~ 24:00
# 15          5.0  매일 17:00 ~ 24:00
#
#                                                이미지url       가게명  \
# 0   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 1   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 2   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 3   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 4   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 5   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 6   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 7   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 8   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 9   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 10  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 11  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 12  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 13  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 14  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 15  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
#
#                        가게 주소                                 메뉴
# 0   대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 1   대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 2   대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 3   대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 4   대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 5   대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 6   대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 7   대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 8   대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 9   대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 10  대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 11  대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 12  대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 13  대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 14  대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 15  대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이

# %%
menu_list
# Out:
# '생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이'

# %% [markdown]
# ---
# ### [1-3]반복문으로 돌리기
# - 리뷰 없으면 continue
# ---

# %%
path = 'C:/chromedriver_win32/chromedriver.exe'
total_df = pd.DataFrame(columns=['리뷰','별점', '리뷰자 평균 평점','리뷰자 누적 리뷰 개수', '영업 시간','이미지url','가게명','가게 주소','메뉴', '카카오 url']) # 컬럼만 조회
driver = webdriver.Chrome(path) # 브라우저 실행
for i in page_urls:
    kakao_url = str(i)
    df = pd.DataFrame()
    time.sleep(1)
    # for page in page_urls:
    driver.get(i) # 식당 데이터 상세화면
    time.sleep(2) # 2초 쉬기
    html = driver.page_source # html 소스 데이터 (page 소스를 html에 세팅)
    soup = BeautifulSoup(html, 'html.parser')
    total_strong = soup.find(name="strong", attrs={"class": "total_evaluation"})
    try:
        tot_num = total_strong.find(name="span", attrs={"class": "color_b"}) # 등록된 리뷰 갯수
    except:
        continue
    
    if int(tot_num.text) == 0:#리뷰가 없을 시 다른 가게 탐색
        continue
    time.sleep(1)


    if (int(tot_num.text)-3)%5 == 0:  
        more_text_num= ((int(tot_num.text)-3)//5)
    else:
        more_text_num= ((int(tot_num.text)-3)//5)+1
        
    if more_text_num == 0:
        pass
    else:
        try:
            for i in range(more_text_num):
                more_text_in_store = driver.find_element_by_css_selector('span.txt_more')  
                actions = ActionChains(driver)#스크롤내리기
                actions.move_to_element(more_text_in_store).perform()
                more_text_in_store.click()
                time.sleep(0.5)
        except:
            continue



    html = driver.page_source # html 소스 데이터 (page 소스를 html에 세팅)
    soup = BeautifulSoup(html, 'html.parser')
    try:        
        store_name = soup.find(name = 'h2', attrs = {'class':'tit_location'})#가게이름
        addr = soup.find(name = 'span', attrs = {'class':'txt_address'})#가게주소
        store_operate_day = soup.find(name = 'span', attrs = {'class':'txt_operation'})#영업일 및 영업시간
        menu = soup.find_all(name = 'span', attrs = {'class':'loss_word'})#메뉴
        
        img_urls = soup.find(name='span', attrs={'class':'bg_present'})
        img_urls = img_urls.get('style')
        start_idx = img_urls.find('url(') + 4  # "url(" 다음 인덱스부터 시작
        end_idx = img_urls.find(')', start_idx)
        url = img_urls[start_idx:end_idx]
        

        total_strong = soup.find(name="strong", attrs={"class": "total_evaluation"})
        tot_num = total_strong.find(name="span", attrs={"class": "color_b"}) # 등록된 리뷰 갯수
        contents_div = soup.find(name='div', attrs={"class": "evaluation_review"}) #리뷰 영역. 별점, 내용
        reviewer_average_score = contents_div.find_all(name="span", attrs={"class": "txt_desc"})#리뷰어의 평균평점
        #reviewer_num = soup.find(name="span", attrs={"class": "text_desc"})#리뷰어의 평균평점
        rates=contents_div.find_all(name="span", attrs={"class": "ico_star star_rate"}) # 별점값 목록
        reviews = contents_div.find_all(name="p", attrs={"class": "txt_comment"}) # 리뷰 목록
    except:
        continue

    
    menu_list = []
    rate_list =[]
    review_list =[]
    reviewer_average_score_list = []
    reviewer_num_list = []


    for i in range(len(rates)):
        rate_value = rates[i].find(name='span', attrs={"class": "ico_star"})
        style_value = rate_value.get('style')
        if style_value == 'width:20%;':
            rate = 1
        elif style_value == 'width:40%;':
            rate = 2
        elif style_value == 'width:60%;':
            rate = 3
        elif style_value == 'width:80%;':
            rate = 4
        elif style_value == 'width:100%;':
            rate = 5
        rate_list.append(rate)    
    for review in reviews:
        rev_span = review.find(name="span")
        if rev_span is not None and rev_span.text:
            rev = rev_span.text
        else:
            rev = ''
        review_list.append(rev)
    for i in range(len(reviewer_average_score)):
        if i%2 == 0:
            reviewer_num_list.append(reviewer_average_score[i].text)
        else:
            reviewer_average_score_list.append(reviewer_average_score[i].text)

    store_name = store_name.text
    try: 
        addr = addr.text
        addr = [i.strip() for i in addr.split('\n')]
        addr = ' '.join(addr)
    except:
        addr = ''
    try:
        store_operate_day = store_operate_day.text
        store_operate_day = store_operate_day.replace('\n', '')
    except:
        store_operate_day = ''
        
    menu_str = ''
    if len(menu)>0:
        for i in menu:
            menu_str += i.text + ' '
        menu_list = menu_str.rstrip()
    else:
        menu_list = ''   
        
    #df생성
    df['리뷰'] = review_list
    df['별점'] = rate_list
    df['리뷰자 평균 평점'] = reviewer_average_score_list
    df['리뷰자 누적 리뷰 개수'] = reviewer_num_list
    df['영업 시간'] = store_operate_day
    df['이미지url'] = url
    df['가게명'] = store_name
    df['가게 주소'] = addr
    df['메뉴'] = menu_list
    df['카카오 url'] = kakao_url 
    
    total_df = pd.concat([total_df,df])
    print(total_df.shape)
    print(total_df.tail(10))
# Out:
# (16, 10)
#                                                    리뷰 별점 리뷰자 평균 평점  \
# 6   밑반찬이 많아서 좋았고 맛도 좋았습니다. 뭉티기도 처음 먹어보는데 쫄깃하고 회먹는 ...  4       3.7
# 7                                            생고기 끝내줘요  5       3.8
# 8   유튜브에 속은 기분. 생고기는 무난하나 굳이 이 가격에 이 웨이팅에? 먹을 정도는 ...  2       3.3
# 9   생고기가 먼저 나오고 밑반찬이 세팅됩니다. 생고기 대자는 생각보다 양이 많지 않습니...  5       3.1
# 10                                               별로예요  1       3.3
# 11                                       덤탱이 썼어요,, 흑흑  1       3.2
# 12  생고기 생각날 때마다 꼭 가는 곳입니다ㅎㅎ예전엔 현지인 단골 분들이 많이 오시는 분...  5       5.0
# 13                 고기는 좋은편이나밑반찬이나가격대비하면 추천할만 하지는 않습니다  3       2.5
# 14                                                     2       2.0
# 15                                                     5       5.0
#
#    리뷰자 누적 리뷰 개수             영업 시간  \
# 6             7  매일 17:00 ~ 24:00
# 7            25  매일 17:00 ~ 24:00
# 8             4  매일 17:00 ~ 24:00
# 9            74  매일 17:00 ~ 24:00
# 10            9  매일 17:00 ~ 24:00
# 11            6  매일 17:00 ~ 24:00
# 12            1  매일 17:00 ~ 24:00
# 13            4  매일 17:00 ~ 24:00
# 14            2  매일 17:00 ~ 24:00
# 15            1  매일 17:00 ~ 24:00
#
#                                                이미지url       가게명  \
# 6   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 7   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 8   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 9   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 10  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 11  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 12  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 13  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 14  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
# 15  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  참조은생고기육회
#
#                        가게 주소                                 메뉴  \
# 6   대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 7   대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 8   대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 9   대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 10  대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 11  대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 12  대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 13  대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 14  대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
# 15  대구 북구 복현로 78 1층 (우)41528  생고기 (소) 탕탕육회 (중) 육회 (소) 육전 소고리짜글이
#
#                                  카카오 url
# 6   https://place.map.kakao.com/16545260
# 7   https://place.map.kakao.com/16545260
# 8   https://place.map.kakao.com/16545260
# 9   https://place.map.kakao.com/16545260
# 10  https://place.map.kakao.com/16545260
# 11  https://place.map.kakao.com/16545260
# 12  https://place.map.kakao.com/16545260
# 13  https://place.map.kakao.com/16545260
# 14  https://place.map.kakao.com/16545260
# 15  https://place.map.kakao.com/16545260
# (36, 10)
#                                                    리뷰 별점 리뷰자 평균 평점  \
# 10                                                     5       5.0
# 11                                             가성비 짱짱  5       4.6
# 12  아 존맛 아묻따 내돈 좀 더 가져가도 됨무한리필은 가고싶은데 타협하기싫을때여기로 간...  5       4.4
# 13  이것저것 커스텀해서 된장도 먹을수 있고, 기계 돌아가는것도 신기했음. 근데 바나나아...  5       3.9
# 14                                               최고에용  5       3.0
# 15  직원분들 친절하시고, 고기 질도 기분 좋게 먹고 올 정도입니다. 가격 대비 만족스럽...  5       3.8
# 16  제가 간 고기 뷔페 중 최고ㅠㅠ!! 뷔페 집에서 서비스나 맛있는 고기를 기대하기 힘...  5       3.7
# 17                고기도 맛있고 사이드 메뉴가 다양해요.고기종류는 적어서 아쉽네요  4       3.9
# 18  제가 본 무한리필 고기집중에 가장 좋았어요 서비스,시설 모두 깔끔하고 고기가 좋은 ...  5       4.4
# 19  고기가 진짜 맛있었어요. 고기뷔페인데 퀼리티가 괜찮네요 사이드도 괜찮았어요. 근처 ...  4       3.2
#
#    리뷰자 누적 리뷰 개수             영업 시간  \
# 10           10  매일 11:00 ~ 23:30
# 11          239  매일 11:00 ~ 23:30
# 12           91  매일 11:00 ~ 23:30
# 13           28  매일 11:00 ~ 23:30
# 14            8  매일 11:00 ~ 23:30
# 15           12  매일 11:00 ~ 23:30
# 16           26  매일 11:00 ~ 23:30
# 17           73  매일 11:00 ~ 23:30
# 18           14  매일 11:00 ~ 23:30
# 19          158  매일 11:00 ~ 23:30
#
#                                                이미지url      가게명  \
# 10  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  포크팬 복현점
# 11  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  포크팬 복현점
# 12  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  포크팬 복현점
# 13  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  포크팬 복현점
# 14  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  포크팬 복현점
# 15  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  포크팬 복현점
# 16  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  포크팬 복현점
# 17  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  포크팬 복현점
# 18  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  포크팬 복현점
# 19  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  포크팬 복현점
#
#                      가게 주소                                   메뉴  \
# 10  대구 북구 동북로 219 (우)41526  런치 대인 (디너, 주말, 공휴일) 초등학생 4~9세 4세 미만
# 11  대구 북구 동북로 219 (우)41526  런치 대인 (디너, 주말, 공휴일) 초등학생 4~9세 4세 미만
# 12  대구 북구 동북로 219 (우)41526  런치 대인 (디너, 주말, 공휴일) 초등학생 4~9세 4세 미만
# 13  대구 북구 동북로 219 (우)41526  런치 대인 (디너, 주말, 공휴일) 초등학생 4~9세 4세 미만
# 14  대구 북구 동북로 219 (우)41526  런치 대인 (디너, 주말, 공휴일) 초등학생 4~9세 4세 미만
# 15  대구 북구 동북로 219 (우)41526  런치 대인 (디너, 주말, 공휴일) 초등학생 4~9세 4세 미만
# 16  대구 북구 동북로 219 (우)41526  런치 대인 (디너, 주말, 공휴일) 초등학생 4~9세 4세 미만
# 17  대구 북구 동북로 219 (우)41526  런치 대인 (디너, 주말, 공휴일) 초등학생 4~9세 4세 미만
# 18  대구 북구 동북로 219 (우)41526  런치 대인 (디너, 주말, 공휴일) 초등학생 4~9세 4세 미만
# 19  대구 북구 동북로 219 (우)41526  런치 대인 (디너, 주말, 공휴일) 초등학생 4~9세 4세 미만
#
#                                   카카오 url
# 10  https://place.map.kakao.com/651046126
# 11  https://place.map.kakao.com/651046126
# 12  https://place.map.kakao.com/651046126
# 13  https://place.map.kakao.com/651046126
# 14  https://place.map.kakao.com/651046126
# 15  https://place.map.kakao.com/651046126
# 16  https://place.map.kakao.com/651046126
# 17  https://place.map.kakao.com/651046126
# 18  https://place.map.kakao.com/651046126
# 19  https://place.map.kakao.com/651046126
# (61, 10)
#                                                    리뷰 별점 리뷰자 평균 평점  \
# 15  훈태형이 찐맛집을 알려주셨네요혼자 치킨 3마리 먹는데 특시켜서 밥두공기에 소주2병 ...  5       3.5
# 16                                                미만잡  5       5.0
# 17            그냥 개맛있습니다.. 그리고 또 사장님 손이크신지 양이 대박이에요...  5       5.0
# 18  1번사진: 그냥 돼지국밥. 밥 안넣고 고기양 체크2번사진: 특 돼지국밥. 고기양 체...  5       2.8
# 19                                               개맛집.  5       4.8
# 20  친구랑 특은 양이 얼마나 되나 궁금해서특으로 시켰는데 전골이 나왔습니다다먹고 정신을...  5       5.0
# 21                      전설의 레전드 세계관 최강자공대생도 특은 뿌수기 힘듦  5       4.5
# 22                          와... 여기 진짜  굿굿  반찬정갈. 양대박  5       4.3
# 23          고기양이 진짜진짜 많아요 특으로 잘못나온줄알았는데 기본양이라네요 맛있습니다  5       3.0
# 24                                          고기양 엄청납니다  5       4.5
#
#    리뷰자 누적 리뷰 개수                      영업 시간  \
# 15           33  월,화,수,목,금,일 10:00 ~ 21:30
# 16            2  월,화,수,목,금,일 10:00 ~ 21:30
# 17            3  월,화,수,목,금,일 10:00 ~ 21:30
# 18           12  월,화,수,목,금,일 10:00 ~ 21:30
# 19           24  월,화,수,목,금,일 10:00 ~ 21:30
# 20            2  월,화,수,목,금,일 10:00 ~ 21:30
# 21          151  월,화,수,목,금,일 10:00 ~ 21:30
# 22           15  월,화,수,목,금,일 10:00 ~ 21:30
# 23            2  월,화,수,목,금,일 10:00 ~ 21:30
# 24            8  월,화,수,목,금,일 10:00 ~ 21:30
#
#                                                이미지url     가게명  \
# 15  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  고향돼지국밥
# 16  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  고향돼지국밥
# 17  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  고향돼지국밥
# 18  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  고향돼지국밥
# 19  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  고향돼지국밥
# 20  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  고향돼지국밥
# 21  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  고향돼지국밥
# 22  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  고향돼지국밥
# 23  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  고향돼지국밥
# 24  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  고향돼지국밥
#
#                         가게 주소 메뉴                                 카카오 url
# 15  대구 동구 경대로 140 2층 (우)41192     https://place.map.kakao.com/1511793421
# 16  대구 동구 경대로 140 2층 (우)41192     https://place.map.kakao.com/1511793421
# 17  대구 동구 경대로 140 2층 (우)41192     https://place.map.kakao.com/1511793421
# 18  대구 동구 경대로 140 2층 (우)41192     https://place.map.kakao.com/1511793421
# 19  대구 동구 경대로 140 2층 (우)41192     https://place.map.kakao.com/1511793421
# 20  대구 동구 경대로 140 2층 (우)41192     https://place.map.kakao.com/1511793421
# 21  대구 동구 경대로 140 2층 (우)41192     https://place.map.kakao.com/1511793421
# 22  대구 동구 경대로 140 2층 (우)41192     https://place.map.kakao.com/1511793421
# 23  대구 동구 경대로 140 2층 (우)41192     https://place.map.kakao.com/1511793421
# 24  대구 동구 경대로 140 2층 (우)41192     https://place.map.kakao.com/1511793421
# (82, 10)
#                                                    리뷰 별점 리뷰자 평균 평점  \
# 11  옛날 부터 먹던 맛 입니다.자주 가고 싶은데 거리가 있어 자주는 못 가지만 변치 않...  5       5.0
# 12  너무너무 별로입니다... 씹을수록 막창냄새도 좀 나고 막창 특유의 고소함이 전혀 없...  1       3.8
# 13                                                     4       3.5
# 14  복현오거리 먹자골목의 내공있는 막창집 소막창 갈비살도 있지만 역시 돼지 막창이 갑이...  4       3.9
# 15  다른곳은 1인분에 150g 8000정도 하는데 120g에 9000원인 것부터 가격대...  1       1.0
# 16   20년전 맛그대로막장 맛이 기가막히고.막창도  고소하니.최고.후식 라면,된장 다맛나요~  5       3.7
# 17                                               돼지막창  4       4.0
# 18                                                     5       4.0
# 19                                     돼지막창 굿!소막창은 별로  4       3.7
# 20                                                     5       4.8
#
#    리뷰자 누적 리뷰 개수             영업 시간  \
# 11            2  매일 12:00 ~ 02:00
# 12           17  매일 12:00 ~ 02:00
# 13           72  매일 12:00 ~ 02:00
# 14          105  매일 12:00 ~ 02:00
# 15            1  매일 12:00 ~ 02:00
# 16           18  매일 12:00 ~ 02:00
# 17          189  매일 12:00 ~ 02:00
# 18           98  매일 12:00 ~ 02:00
# 19          645  매일 12:00 ~ 02:00
# 20           10  매일 12:00 ~ 02:00
#
#                                                이미지url        가게명  \
# 11  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  싱글벙글막창전문점
# 12  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  싱글벙글막창전문점
# 13  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  싱글벙글막창전문점
# 14  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  싱글벙글막창전문점
# 15  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  싱글벙글막창전문점
# 16  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  싱글벙글막창전문점
# 17  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  싱글벙글막창전문점
# 18  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  싱글벙글막창전문점
# 19  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  싱글벙글막창전문점
# 20  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  싱글벙글막창전문점
#
#                       가게 주소                                            메뉴  \
# 11  대구 북구 경진로1길 13 (우)41562  돼지막창 (120g) 소막창 (120g) 소갈비살 (120g) 후식우동 후식라면
# 12  대구 북구 경진로1길 13 (우)41562  돼지막창 (120g) 소막창 (120g) 소갈비살 (120g) 후식우동 후식라면
# 13  대구 북구 경진로1길 13 (우)41562  돼지막창 (120g) 소막창 (120g) 소갈비살 (120g) 후식우동 후식라면
# 14  대구 북구 경진로1길 13 (우)41562  돼지막창 (120g) 소막창 (120g) 소갈비살 (120g) 후식우동 후식라면
# 15  대구 북구 경진로1길 13 (우)41562  돼지막창 (120g) 소막창 (120g) 소갈비살 (120g) 후식우동 후식라면
# 16  대구 북구 경진로1길 13 (우)41562  돼지막창 (120g) 소막창 (120g) 소갈비살 (120g) 후식우동 후식라면
# 17  대구 북구 경진로1길 13 (우)41562  돼지막창 (120g) 소막창 (120g) 소갈비살 (120g) 후식우동 후식라면
# 18  대구 북구 경진로1길 13 (우)41562  돼지막창 (120g) 소막창 (120g) 소갈비살 (120g) 후식우동 후식라면
# 19  대구 북구 경진로1길 13 (우)41562  돼지막창 (120g) 소막창 (120g) 소갈비살 (120g) 후식우동 후식라면
# 20  대구 북구 경진로1길 13 (우)41562  돼지막창 (120g) 소막창 (120g) 소갈비살 (120g) 후식우동 후식라면
#
#                                  카카오 url
# 11  https://place.map.kakao.com/25039377
# 12  https://place.map.kakao.com/25039377
# 13  https://place.map.kakao.com/25039377
# 14  https://place.map.kakao.com/25039377
# 15  https://place.map.kakao.com/25039377
# 16  https://place.map.kakao.com/25039377
# 17  https://place.map.kakao.com/25039377
# 18  https://place.map.kakao.com/25039377
# 19  https://place.map.kakao.com/25039377
# 20  https://place.map.kakao.com/25039377
# (89, 10)
#                                                   리뷰 별점 리뷰자 평균 평점  \
# 18                                                    5       4.0
# 19                                    돼지막창 굿!소막창은 별로  4       3.7
# 20                                                    5       4.8
# 0                                                     5       3.6
# 1                                            양많고 좋네요  3       3.5
# 2                 양은  좀 되나 호불호가  갈리는 맛 반찬도 가격대비 애매함.  1       1.0
# 3                                            완전 대박~~  5       5.0
# 4   뭉티기 생고기 집 중에 최고예요:D  반찬도 하나하나 다 맛있고 가고 또가고 싶은곳!!  5       5.0
# 5         밑반찬 겁~나~ 많음! 맛도 겁~나~좋음!메인 생고기 육회는 당연히 조으다~  5       3.7
# 6                                                     5       3.5
#
#    리뷰자 누적 리뷰 개수             영업 시간  \
# 18           98  매일 12:00 ~ 02:00
# 19          645  매일 12:00 ~ 02:00
# 20           10  매일 12:00 ~ 02:00
# 0            53  매일 16:00 ~ 02:00
# 1            94  매일 16:00 ~ 02:00
# 2             1  매일 16:00 ~ 02:00
# 3             1  매일 16:00 ~ 02:00
# 4             1  매일 16:00 ~ 02:00
# 5             3  매일 16:00 ~ 02:00
# 6            86  매일 16:00 ~ 02:00
#
#                                                이미지url         가게명  \
# 18  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...   싱글벙글막창전문점
# 19  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...   싱글벙글막창전문점
# 20  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...   싱글벙글막창전문점
# 0   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  퇴근길생고기 복현점
# 1   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  퇴근길생고기 복현점
# 2   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  퇴근길생고기 복현점
# 3   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  퇴근길생고기 복현점
# 4   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  퇴근길생고기 복현점
# 5   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  퇴근길생고기 복현점
# 6   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  퇴근길생고기 복현점
#
#                        가게 주소  \
# 18   대구 북구 경진로1길 13 (우)41562
# 19   대구 북구 경진로1길 13 (우)41562
# 20   대구 북구 경진로1길 13 (우)41562
# 0   대구 북구 대학로 152-1 (우)41562
# 1   대구 북구 대학로 152-1 (우)41562
# 2   대구 북구 대학로 152-1 (우)41562
# 3   대구 북구 대학로 152-1 (우)41562
# 4   대구 북구 대학로 152-1 (우)41562
# 5   대구 북구 대학로 152-1 (우)41562
# 6   대구 북구 대학로 152-1 (우)41562
#
#                                                    메뉴  \
# 18       돼지막창 (120g) 소막창 (120g) 소갈비살 (120g) 후식우동 후식라면
# 19       돼지막창 (120g) 소막창 (120g) 소갈비살 (120g) 후식우동 후식라면
# 20       돼지막창 (120g) 소막창 (120g) 소갈비살 (120g) 후식우동 후식라면
# 0   한우생고기+한우육회 (200g+220g) 한우생고기 (소) 한우육회 (소) 대창구이...
# 1   한우생고기+한우육회 (200g+220g) 한우생고기 (소) 한우육회 (소) 대창구이...
# 2   한우생고기+한우육회 (200g+220g) 한우생고기 (소) 한우육회 (소) 대창구이...
# 3   한우생고기+한우육회 (200g+220g) 한우생고기 (소) 한우육회 (소) 대창구이...
# 4   한우생고기+한우육회 (200g+220g) 한우생고기 (소) 한우육회 (소) 대창구이...
# 5   한우생고기+한우육회 (200g+220g) 한우생고기 (소) 한우육회 (소) 대창구이...
# 6   한우생고기+한우육회 (200g+220g) 한우생고기 (소) 한우육회 (소) 대창구이...
#
#                                   카카오 url
# 18   https://place.map.kakao.com/25039377
# 19   https://place.map.kakao.com/25039377
# 20   https://place.map.kakao.com/25039377
# 0   https://place.map.kakao.com/718787858
# 1   https://place.map.kakao.com/718787858
# 2   https://place.map.kakao.com/718787858
# 3   https://place.map.kakao.com/718787858
# 4   https://place.map.kakao.com/718787858
# 5   https://place.map.kakao.com/718787858
# 6   https://place.map.kakao.com/718787858
# (107, 10)
#                                                    리뷰 별점 리뷰자 평균 평점  \
# 8     초코크로플? 저거 진짜 맛있었어요.. 날씨 좋을땐 경치도 최고   너무너무 추천합니다  5       3.8
# 9                            분위기 작살나요얼그레이 케이크 맛도리ㅠㅠ❤️  5       4.9
# 10                   뷰도좋고 커피도맛잇고 넓어서 자리걱정도없는거같아용 자주올듯  5       3.0
# 11                                    복현동에서 젤 좋아하는 카페  5       3.7
# 12  첫 방문에 아메리카노를 주문하고 원두를 골랐는데 재차 확인도 없이 핸드드립으로 바꾸...  1       1.0
# 13  경치랑 음료, 베이커리 맛은 좋은데 주차장이랑 창문에 벌레(팅커벨)가 너어어무 많아요ㅜㅜ  3       3.1
# 14                                      여기 초코크로플 핵마싯음  4       3.3
# 15                             음료개맛없음 케이크도 딱히,,,뷰는 좋음  1       3.3
# 16                            뷰가 정말 좋고 케이크 데코가 고급스러워요  5       5.0
# 17                                           뷰 자리 맛 굿  5       4.0
#
#    리뷰자 누적 리뷰 개수             영업 시간  \
# 8            13  매일 10:00 ~ 23:00
# 9            32  매일 10:00 ~ 23:00
# 10            2  매일 10:00 ~ 23:00
# 11           19  매일 10:00 ~ 23:00
# 12            2  매일 10:00 ~ 23:00
# 13           20  매일 10:00 ~ 23:00
# 14           13  매일 10:00 ~ 23:00
# 15           18  매일 10:00 ~ 23:00
# 16            5  매일 10:00 ~ 23:00
# 17            4  매일 10:00 ~ 23:00
#
#                                                이미지url          가게명  \
# 8   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스테이블모먼트 반석점
# 9   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스테이블모먼트 반석점
# 10  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스테이블모먼트 반석점
# 11  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스테이블모먼트 반석점
# 12  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스테이블모먼트 반석점
# 13  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스테이블모먼트 반석점
# 14  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스테이블모먼트 반석점
# 15  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스테이블모먼트 반석점
# 16  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스테이블모먼트 반석점
# 17  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스테이블모먼트 반석점
#
#                                       가게 주소  \
# 8   대구 북구 복현로8길 19-36 지하1층, 지상1,2층 (우)41528
# 9   대구 북구 복현로8길 19-36 지하1층, 지상1,2층 (우)41528
# 10  대구 북구 복현로8길 19-36 지하1층, 지상1,2층 (우)41528
# 11  대구 북구 복현로8길 19-36 지하1층, 지상1,2층 (우)41528
# 12  대구 북구 복현로8길 19-36 지하1층, 지상1,2층 (우)41528
# 13  대구 북구 복현로8길 19-36 지하1층, 지상1,2층 (우)41528
# 14  대구 북구 복현로8길 19-36 지하1층, 지상1,2층 (우)41528
# 15  대구 북구 복현로8길 19-36 지하1층, 지상1,2층 (우)41528
# 16  대구 북구 복현로8길 19-36 지하1층, 지상1,2층 (우)41528
# 17  대구 북구 복현로8길 19-36 지하1층, 지상1,2층 (우)41528
#
#                                    메뉴                                카카오 url
# 8   에스프레소 아메리카노 카페라떼 레몬에이드 플레인 요거트스무디  https://place.map.kakao.com/740189884
# 9   에스프레소 아메리카노 카페라떼 레몬에이드 플레인 요거트스무디  https://place.map.kakao.com/740189884
# 10  에스프레소 아메리카노 카페라떼 레몬에이드 플레인 요거트스무디  https://place.map.kakao.com/740189884
# 11  에스프레소 아메리카노 카페라떼 레몬에이드 플레인 요거트스무디  https://place.map.kakao.com/740189884
# 12  에스프레소 아메리카노 카페라떼 레몬에이드 플레인 요거트스무디  https://place.map.kakao.com/740189884
# 13  에스프레소 아메리카노 카페라떼 레몬에이드 플레인 요거트스무디  https://place.map.kakao.com/740189884
# 14  에스프레소 아메리카노 카페라떼 레몬에이드 플레인 요거트스무디  https://place.map.kakao.com/740189884
# 15  에스프레소 아메리카노 카페라떼 레몬에이드 플레인 요거트스무디  https://place.map.kakao.com/740189884
# 16  에스프레소 아메리카노 카페라떼 레몬에이드 플레인 요거트스무디  https://place.map.kakao.com/740189884
# 17  에스프레소 아메리카노 카페라떼 레몬에이드 플레인 요거트스무디  https://place.map.kakao.com/740189884
# (119, 10)
#                                                    리뷰 별점 리뷰자 평균 평점  \
# 2   와 ㄹㅇ 와… 오ㅓ… 막창 왤케 맛있어… 여러분 그 빨간소스 있는데 그거 살짝 매콤...  5       3.6
# 3   오랜만에 리뷰씁니다 1.장점부드럽고 잘앂히고 맛있는 막창을 먹을수있다2.단점평소 쫄...  5       4.5
# 4                       정말 맛있어요 ㅎㅎ 막창 냄새도 안나고 최고에요 ㅎㅎ  5       3.9
# 5   대구 여행와서 맛있는 막창을 먹고내려오고 싶어서 한참을 찾아다가 간 곳인데너무 만족...  5       5.0
# 6                                    맛있네요 저렴친절맛있 동네맛집  5       4.3
# 7                                                      5       4.0
# 8   대구 막창 최고존엄타지에 사는손님이 막창 먹으러 대구 온다하면 꼭 데리러오는 막창맛...  5       4.1
# 9   안동막창의 비법을 그대로 전수받았다던데  부드러우면서도 쫄깃한 식감과 잡내없이 고소...  5       5.0
# 10                                      jmt 진정한 맛집입니다  5       3.9
# 11  제가 막창을 좋아하지 않는데 이집 막창은 정말 맛있더라구요~아마 숨은 맛집이 아닐까...  5       5.0
#
#    리뷰자 누적 리뷰 개수 영업 시간                                             이미지url  \
# 2            72        '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...
# 3             8        '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...
# 4             8        '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...
# 5             2        '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...
# 6            67        '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...
# 7            25        '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...
# 8            32        '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...
# 9             4        '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...
# 10           83        '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...
# 11            1        '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...
#
#      가게명                    가게 주소  \
# 2   안동막창  대구 북구 경진로1길 15 (우)41562
# 3   안동막창  대구 북구 경진로1길 15 (우)41562
# 4   안동막창  대구 북구 경진로1길 15 (우)41562
# 5   안동막창  대구 북구 경진로1길 15 (우)41562
# 6   안동막창  대구 북구 경진로1길 15 (우)41562
# 7   안동막창  대구 북구 경진로1길 15 (우)41562
# 8   안동막창  대구 북구 경진로1길 15 (우)41562
# 9   안동막창  대구 북구 경진로1길 15 (우)41562
# 10  안동막창  대구 북구 경진로1길 15 (우)41562
# 11  안동막창  대구 북구 경진로1길 15 (우)41562
#
#                                                    메뉴  \
# 2   안동막창 (150g) 빨간막창 (150g) 양념갈매기 (130g) 빨간갈매기 (13...
# 3   안동막창 (150g) 빨간막창 (150g) 양념갈매기 (130g) 빨간갈매기 (13...
# 4   안동막창 (150g) 빨간막창 (150g) 양념갈매기 (130g) 빨간갈매기 (13...
# 5   안동막창 (150g) 빨간막창 (150g) 양념갈매기 (130g) 빨간갈매기 (13...
# 6   안동막창 (150g) 빨간막창 (150g) 양념갈매기 (130g) 빨간갈매기 (13...
# 7   안동막창 (150g) 빨간막창 (150g) 양념갈매기 (130g) 빨간갈매기 (13...
# 8   안동막창 (150g) 빨간막창 (150g) 양념갈매기 (130g) 빨간갈매기 (13...
# 9   안동막창 (150g) 빨간막창 (150g) 양념갈매기 (130g) 빨간갈매기 (13...
# 10  안동막창 (150g) 빨간막창 (150g) 양념갈매기 (130g) 빨간갈매기 (13...
# 11  안동막창 (150g) 빨간막창 (150g) 양념갈매기 (130g) 빨간갈매기 (13...
#
#                                  카카오 url
# 2   https://place.map.kakao.com/14534791
# 3   https://place.map.kakao.com/14534791
# 4   https://place.map.kakao.com/14534791
# 5   https://place.map.kakao.com/14534791
# 6   https://place.map.kakao.com/14534791
# 7   https://place.map.kakao.com/14534791
# 8   https://place.map.kakao.com/14534791
# 9   https://place.map.kakao.com/14534791
# 10  https://place.map.kakao.com/14534791
# 11  https://place.map.kakao.com/14534791
# (129, 10)
#                                                   리뷰 별점 리뷰자 평균 평점  \
# 0  갈비찜 중자 부터인데 39000원 내고 먹기 개 ㅎㅌㅊ ㄹㅇ 뼈가 70프로고 고기가...  1       1.7
# 1  여기는 물비빔냉면과 만두 맛집입니다..!뭘 어떻게 만들었는지 이 두가지 음식은 정말...  5       4.7
# 2  특냉면 가격이 12,000원인데 냉면 다 먹을 때까지 온육수 준비 중이라고 해서 육...  1       2.7
# 3              그냥저냥 그래요 갈비탕가격에 비해 맛은 가격값을 못하는 느낌입니다…  3       3.3
# 4                                    잘먹었습니다^^ 아주 맛있게  5       3.2
# 5         직원 불친절. 음식 잘못 가져다놓고 오히려 언성높임. 가격대비 맛있지 않음.  1       1.0
# 6                                                     2       3.8
# 7                                  갈비국수먹음. 그냥저냥 먹을만함  2       3.2
# 8     맛도 위생도 대박서구쪽에 본점 갔었는데이렇게 가까운곳에새로 생기다니맛도 똑같네요^^  5       5.0
# 9                                         수량제한하는점이 굿  3       3.7
#
#   리뷰자 누적 리뷰 개수             영업 시간  \
# 0            6  매일 09:30 ~ 21:00
# 1           18  매일 09:30 ~ 21:00
# 2            3  매일 09:30 ~ 21:00
# 3            4  매일 09:30 ~ 21:00
# 4            6  매일 09:30 ~ 21:00
# 5            1  매일 09:30 ~ 21:00
# 6           69  매일 09:30 ~ 21:00
# 7          158  매일 09:30 ~ 21:00
# 8           32  매일 09:30 ~ 21:00
# 9          296  매일 09:30 ~ 21:00
#
#                                               이미지url       가게명  \
# 0  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  교동면옥 복현점
# 1  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  교동면옥 복현점
# 2  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  교동면옥 복현점
# 3  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  교동면옥 복현점
# 4  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  교동면옥 복현점
# 5  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  교동면옥 복현점
# 6  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  교동면옥 복현점
# 7  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  교동면옥 복현점
# 8  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  교동면옥 복현점
# 9  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  교동면옥 복현점
#
#                       가게 주소                             메뉴  \
# 0  대구 북구 동북로 303-1 (우)41530  교동특냉면 육전물비빔면 육전물냉면 육전비빔냉면 갈비탕
# 1  대구 북구 동북로 303-1 (우)41530  교동특냉면 육전물비빔면 육전물냉면 육전비빔냉면 갈비탕
# 2  대구 북구 동북로 303-1 (우)41530  교동특냉면 육전물비빔면 육전물냉면 육전비빔냉면 갈비탕
# 3  대구 북구 동북로 303-1 (우)41530  교동특냉면 육전물비빔면 육전물냉면 육전비빔냉면 갈비탕
# 4  대구 북구 동북로 303-1 (우)41530  교동특냉면 육전물비빔면 육전물냉면 육전비빔냉면 갈비탕
# 5  대구 북구 동북로 303-1 (우)41530  교동특냉면 육전물비빔면 육전물냉면 육전비빔냉면 갈비탕
# 6  대구 북구 동북로 303-1 (우)41530  교동특냉면 육전물비빔면 육전물냉면 육전비빔냉면 갈비탕
# 7  대구 북구 동북로 303-1 (우)41530  교동특냉면 육전물비빔면 육전물냉면 육전비빔냉면 갈비탕
# 8  대구 북구 동북로 303-1 (우)41530  교동특냉면 육전물비빔면 육전물냉면 육전비빔냉면 갈비탕
# 9  대구 북구 동북로 303-1 (우)41530  교동특냉면 육전물비빔면 육전물냉면 육전비빔냉면 갈비탕
#
#                                   카카오 url
# 0  https://place.map.kakao.com/1678398705
# 1  https://place.map.kakao.com/1678398705
# 2  https://place.map.kakao.com/1678398705
# 3  https://place.map.kakao.com/1678398705
# 4  https://place.map.kakao.com/1678398705
# 5  https://place.map.kakao.com/1678398705
# 6  https://place.map.kakao.com/1678398705
# 7  https://place.map.kakao.com/1678398705
# 8  https://place.map.kakao.com/1678398705
# 9  https://place.map.kakao.com/1678398705
# (167, 10)
#                                                    리뷰 별점 리뷰자 평균 평점  \
# 28                                    쿠폰 못씀. 알바생 불친절.  1       2.7
# 29  늘 갈때마다 괜히갔다는 느낌이 드는 곳 인데,  솔직히 겁나 바쁜지점 같은데 알바생...  1       3.9
# 30                               드럽게 맛없음 김자튀김은 소금튀김인줄  1       3.0
# 31  햄버거맛은 평범한 맥날인데 별점 5점 다깎을 정도로 감튀가 짬. 소금을 드시라고 세...  1       3.1
# 32  20년4월9일 밤에 주방에 마스크랑 모자 착용하지 않은 흰색 셔츠 녀ㄴ자는 뭔가요?...  1       3.9
# 33  진짜 웬만하면 제가 카맵에 이런 리뷰 안 올리는데... 크루 왜 이렇게 싸가지없어요...  1       4.2
# 34  패스트푸드면 패스트푸드답게 적당한 가격에 맞는 합당한 서비스와 품질이 따라와야지 가...  1       3.0
# 35                     손님이 많으면 직원도 늘려라 바빠서 그런지 싸갈스바갈스  1       3.2
# 36  버거 세트에서 스프라이트로 보내달랬는데 콜라를 보내질않나 같이 시킨 스프라이트는 밍...  1       1.0
# 37  일반버거들도 아니고 시그니쳐 버건데.. 조금만 더 성의를 보여주셨으면 합니다. 사진...  3       3.0
#
#    리뷰자 누적 리뷰 개수             영업 시간  \
# 28           17  매일 08:00 ~ 24:00
# 29           28  매일 08:00 ~ 24:00
# 30            2  매일 08:00 ~ 24:00
# 31            9  매일 08:00 ~ 24:00
# 32           73  매일 08:00 ~ 24:00
# 33            6  매일 08:00 ~ 24:00
# 34            2  매일 08:00 ~ 24:00
# 35          158  매일 08:00 ~ 24:00
# 36            1  매일 08:00 ~ 24:00
# 37            3  매일 08:00 ~ 24:00
#
#                                                이미지url           가게명  \
# 28  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  맥도날드 대구복현DT점
# 29  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  맥도날드 대구복현DT점
# 30  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  맥도날드 대구복현DT점
# 31  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  맥도날드 대구복현DT점
# 32  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  맥도날드 대구복현DT점
# 33  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  맥도날드 대구복현DT점
# 34  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  맥도날드 대구복현DT점
# 35  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  맥도날드 대구복현DT점
# 36  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  맥도날드 대구복현DT점
# 37  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  맥도날드 대구복현DT점
#
#                      가게 주소                                                 메뉴  \
# 28  대구 북구 동북로 303 (우)41530  빅맥 더블 불고기 버거 슈비버거 슈슈버거 맥스파이시 상하이 버거 아메리카노 1955...
# 29  대구 북구 동북로 303 (우)41530  빅맥 더블 불고기 버거 슈비버거 슈슈버거 맥스파이시 상하이 버거 아메리카노 1955...
# 30  대구 북구 동북로 303 (우)41530  빅맥 더블 불고기 버거 슈비버거 슈슈버거 맥스파이시 상하이 버거 아메리카노 1955...
# 31  대구 북구 동북로 303 (우)41530  빅맥 더블 불고기 버거 슈비버거 슈슈버거 맥스파이시 상하이 버거 아메리카노 1955...
# 32  대구 북구 동북로 303 (우)41530  빅맥 더블 불고기 버거 슈비버거 슈슈버거 맥스파이시 상하이 버거 아메리카노 1955...
# 33  대구 북구 동북로 303 (우)41530  빅맥 더블 불고기 버거 슈비버거 슈슈버거 맥스파이시 상하이 버거 아메리카노 1955...
# 34  대구 북구 동북로 303 (우)41530  빅맥 더블 불고기 버거 슈비버거 슈슈버거 맥스파이시 상하이 버거 아메리카노 1955...
# 35  대구 북구 동북로 303 (우)41530  빅맥 더블 불고기 버거 슈비버거 슈슈버거 맥스파이시 상하이 버거 아메리카노 1955...
# 36  대구 북구 동북로 303 (우)41530  빅맥 더블 불고기 버거 슈비버거 슈슈버거 맥스파이시 상하이 버거 아메리카노 1955...
# 37  대구 북구 동북로 303 (우)41530  빅맥 더블 불고기 버거 슈비버거 슈슈버거 맥스파이시 상하이 버거 아메리카노 1955...
#
#                                  카카오 url
# 28  https://place.map.kakao.com/27177669
# 29  https://place.map.kakao.com/27177669
# 30  https://place.map.kakao.com/27177669
# 31  https://place.map.kakao.com/27177669
# 32  https://place.map.kakao.com/27177669
# 33  https://place.map.kakao.com/27177669
# 34  https://place.map.kakao.com/27177669
# 35  https://place.map.kakao.com/27177669
# 36  https://place.map.kakao.com/27177669
# 37  https://place.map.kakao.com/27177669
# (176, 10)
#                                                    리뷰 별점 리뷰자 평균 평점  \
# 37  일반버거들도 아니고 시그니쳐 버건데.. 조금만 더 성의를 보여주셨으면 합니다. 사진...  3       3.0
# 0   참치는 무조건 비추 입니다. 코스는 4만, 5만 6만 입니다.참치 포함된 세트가 5...  1       2.6
# 1   저녁식사 하러간 곳인데 식사 말고도 맛있는게 엄청 나오네요... 직원분도 친절하시고...  5       5.0
# 2                                          친절 맛 다 대만족  5       5.0
# 3                        물회 존맛 음식맛 정갈하고 잘나옴 튀김도 진짜 잘함  5       3.8
# 4                                                 좋아요  4       4.3
# 5                          서비스와 맛 모두 만족합니다 단독룸이라 좋았네요  5       5.0
# 6   서비스가 엉망입니다시킨 음식 기억 못해서 두번 이야기해야하고 코스요리도 덜나왔는지 ...  2       3.1
# 7                                                   굿  4       3.7
# 8   깔끔하고 고급진 분위기 같은곳에서 드시길 원하시는 분에게 추천드립니다. 회랑 튀김들...  3       3.2
#
#    리뷰자 누적 리뷰 개수             영업 시간  \
# 37            3  매일 08:00 ~ 24:00
# 0             9
# 1             1
# 2             6
# 3            12
# 4            32
# 5             1
# 6            46
# 7           296
# 8           158
#
#                                                이미지url           가게명  \
# 37  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  맥도날드 대구복현DT점
# 0   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...           정동진
# 1   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...           정동진
# 2   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...           정동진
# 3   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...           정동진
# 4   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...           정동진
# 5   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...           정동진
# 6   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...           정동진
# 7   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...           정동진
# 8   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...           정동진
#
#                              가게 주소  \
# 37          대구 북구 동북로 303 (우)41530
# 0   대구 북구 동북로 279 삼성빌딩 1층 (우)41529
# 1   대구 북구 동북로 279 삼성빌딩 1층 (우)41529
# 2   대구 북구 동북로 279 삼성빌딩 1층 (우)41529
# 3   대구 북구 동북로 279 삼성빌딩 1층 (우)41529
# 4   대구 북구 동북로 279 삼성빌딩 1층 (우)41529
# 5   대구 북구 동북로 279 삼성빌딩 1층 (우)41529
# 6   대구 북구 동북로 279 삼성빌딩 1층 (우)41529
# 7   대구 북구 동북로 279 삼성빌딩 1층 (우)41529
# 8   대구 북구 동북로 279 삼성빌딩 1층 (우)41529
#
#                                                    메뉴  \
# 37  빅맥 더블 불고기 버거 슈비버거 슈슈버거 맥스파이시 상하이 버거 아메리카노 1955...
# 0    모듬회(소) 광어,우럭(소) 돔,농어(소) 세꼬시(소) 잡어,게르치(소) 해물모듬(중)
# 1    모듬회(소) 광어,우럭(소) 돔,농어(소) 세꼬시(소) 잡어,게르치(소) 해물모듬(중)
# 2    모듬회(소) 광어,우럭(소) 돔,농어(소) 세꼬시(소) 잡어,게르치(소) 해물모듬(중)
# 3    모듬회(소) 광어,우럭(소) 돔,농어(소) 세꼬시(소) 잡어,게르치(소) 해물모듬(중)
# 4    모듬회(소) 광어,우럭(소) 돔,농어(소) 세꼬시(소) 잡어,게르치(소) 해물모듬(중)
# 5    모듬회(소) 광어,우럭(소) 돔,농어(소) 세꼬시(소) 잡어,게르치(소) 해물모듬(중)
# 6    모듬회(소) 광어,우럭(소) 돔,농어(소) 세꼬시(소) 잡어,게르치(소) 해물모듬(중)
# 7    모듬회(소) 광어,우럭(소) 돔,농어(소) 세꼬시(소) 잡어,게르치(소) 해물모듬(중)
# 8    모듬회(소) 광어,우럭(소) 돔,농어(소) 세꼬시(소) 잡어,게르치(소) 해물모듬(중)
#
#                                  카카오 url
# 37  https://place.map.kakao.com/27177669
# 0    https://place.map.kakao.com/7832325
# 1    https://place.map.kakao.com/7832325
# 2    https://place.map.kakao.com/7832325
# 3    https://place.map.kakao.com/7832325
# 4    https://place.map.kakao.com/7832325
# 5    https://place.map.kakao.com/7832325
# 6    https://place.map.kakao.com/7832325
# 7    https://place.map.kakao.com/7832325
# 8    https://place.map.kakao.com/7832325
# (182, 10)
#                                                   리뷰 별점 리뷰자 평균 평점  \
# 5                         서비스와 맛 모두 만족합니다 단독룸이라 좋았네요  5       5.0
# 6  서비스가 엉망입니다시킨 음식 기억 못해서 두번 이야기해야하고 코스요리도 덜나왔는지 ...  2       3.1
# 7                                                  굿  4       3.7
# 8  깔끔하고 고급진 분위기 같은곳에서 드시길 원하시는 분에게 추천드립니다. 회랑 튀김들...  3       3.2
# 0                                         서비스정신 마이너스  1       3.9
# 1  아메리카노 마시고 20분 만에 나옴. 주차등록 할려니 안됨. 직원에게 물어보니, 만...  1       3.1
# 2                         넓고 잘 관리 되어 있으며직원들 늘 생기넘치심😉  5       4.1
# 3                              ㅋㅋㅋㅋㅋㅋㅋ 0시까지 하는 곳 찾았다  5       3.2
# 4                                                     5       4.3
# 5                            넓고 관리 잘됨, 카운터 남자직원이 친절함  5       3.6
#
#   리뷰자 누적 리뷰 개수             영업 시간  \
# 5            1
# 6           46
# 7          296
# 8          158
# 0           21  매일 07:00 ~ 23:00
# 1           80  매일 07:00 ~ 23:00
# 2           40  매일 07:00 ~ 23:00
# 3          120  매일 07:00 ~ 23:00
# 4           32  매일 07:00 ~ 23:00
# 5           72  매일 07:00 ~ 23:00
#
#                                               이미지url           가게명  \
# 5  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...           정동진
# 6  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...           정동진
# 7  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...           정동진
# 8  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...           정동진
# 0  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스타벅스 대구복현DT점
# 1  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스타벅스 대구복현DT점
# 2  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스타벅스 대구복현DT점
# 3  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스타벅스 대구복현DT점
# 4  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스타벅스 대구복현DT점
# 5  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스타벅스 대구복현DT점
#
#                             가게 주소  \
# 5  대구 북구 동북로 279 삼성빌딩 1층 (우)41529
# 6  대구 북구 동북로 279 삼성빌딩 1층 (우)41529
# 7  대구 북구 동북로 279 삼성빌딩 1층 (우)41529
# 8  대구 북구 동북로 279 삼성빌딩 1층 (우)41529
# 0          대구 북구 대학로 150 (우)41562
# 1          대구 북구 대학로 150 (우)41562
# 2          대구 북구 대학로 150 (우)41562
# 3          대구 북구 대학로 150 (우)41562
# 4          대구 북구 대학로 150 (우)41562
# 5          대구 북구 대학로 150 (우)41562
#
#                                                   메뉴  \
# 5   모듬회(소) 광어,우럭(소) 돔,농어(소) 세꼬시(소) 잡어,게르치(소) 해물모듬(중)
# 6   모듬회(소) 광어,우럭(소) 돔,농어(소) 세꼬시(소) 잡어,게르치(소) 해물모듬(중)
# 7   모듬회(소) 광어,우럭(소) 돔,농어(소) 세꼬시(소) 잡어,게르치(소) 해물모듬(중)
# 8   모듬회(소) 광어,우럭(소) 돔,농어(소) 세꼬시(소) 잡어,게르치(소) 해물모듬(중)
# 0  아이스 슈크림 라떼 슈크림 라떼 봄 딸기 라떼 리저브 나이트로 바질 레몬 셔벗 블렌...
# 1  아이스 슈크림 라떼 슈크림 라떼 봄 딸기 라떼 리저브 나이트로 바질 레몬 셔벗 블렌...
# 2  아이스 슈크림 라떼 슈크림 라떼 봄 딸기 라떼 리저브 나이트로 바질 레몬 셔벗 블렌...
# 3  아이스 슈크림 라떼 슈크림 라떼 봄 딸기 라떼 리저브 나이트로 바질 레몬 셔벗 블렌...
# 4  아이스 슈크림 라떼 슈크림 라떼 봄 딸기 라떼 리저브 나이트로 바질 레몬 셔벗 블렌...
# 5  아이스 슈크림 라떼 슈크림 라떼 봄 딸기 라떼 리저브 나이트로 바질 레몬 셔벗 블렌...
#
#                                 카카오 url
# 5   https://place.map.kakao.com/7832325
# 6   https://place.map.kakao.com/7832325
# 7   https://place.map.kakao.com/7832325
# 8   https://place.map.kakao.com/7832325
# 0  https://place.map.kakao.com/34247199
# 1  https://place.map.kakao.com/34247199
# 2  https://place.map.kakao.com/34247199
# 3  https://place.map.kakao.com/34247199
# 4  https://place.map.kakao.com/34247199
# 5  https://place.map.kakao.com/34247199
# (190, 10)
#                                                   리뷰 별점 리뷰자 평균 평점  \
# 4                                                     5       4.3
# 5                            넓고 관리 잘됨, 카운터 남자직원이 친절함  5       3.6
# 0                                                     1       1.4
# 1                                       무난하고 가성비 좋다.  4       3.8
# 2  너무맛있어요 사장님도 넘 친절하시고 국밥도 얼큰하고 고소한게 너무 맛있어용!! 근처...  5       5.0
# 3                                  양 많고 맛있게 잘 먹었습니다!  5       5.0
# 4      양도 많고 국밥도 맛있고 밑반찬도 너무 맛있어요 자주 가는 단골 가게랍니다 ㅠㅠ!  5       5.0
# 5  얼큰이가 정말 맛있습니다. 매운거 못드시는분은 덜 맵게가 가능하다고 하니 미리말하면...  5       5.0
# 6                                      또들를게요 맛있네요~ㅎㅎ  5       5.0
# 7                                            그냥 그렇네요  3       3.2
#
#   리뷰자 누적 리뷰 개수             영업 시간  \
# 4           32  매일 07:00 ~ 23:00
# 5           72  매일 07:00 ~ 23:00
# 0           30   월 09:00 ~ 24:00
# 1          501   월 09:00 ~ 24:00
# 2            2   월 09:00 ~ 24:00
# 3            1   월 09:00 ~ 24:00
# 4            1   월 09:00 ~ 24:00
# 5            1   월 09:00 ~ 24:00
# 6            2   월 09:00 ~ 24:00
# 7          158   월 09:00 ~ 24:00
#
#                                               이미지url           가게명  \
# 4  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스타벅스 대구복현DT점
# 5  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  스타벅스 대구복현DT점
# 0  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...      찐한부산돼지국밥
# 1  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...      찐한부산돼지국밥
# 2  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...      찐한부산돼지국밥
# 3  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...      찐한부산돼지국밥
# 4  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...      찐한부산돼지국밥
# 5  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...      찐한부산돼지국밥
# 6  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...      찐한부산돼지국밥
# 7  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...      찐한부산돼지국밥
#
#                     가게 주소                                                 메뉴  \
# 4  대구 북구 대학로 150 (우)41562  아이스 슈크림 라떼 슈크림 라떼 봄 딸기 라떼 리저브 나이트로 바질 레몬 셔벗 블렌...
# 5  대구 북구 대학로 150 (우)41562  아이스 슈크림 라떼 슈크림 라떼 봄 딸기 라떼 리저브 나이트로 바질 레몬 셔벗 블렌...
# 0  대구 북구 동북로 275 (우)41529           보통 돼지국밥 보통 내장국밥 수육 (소) 모듬순대 (소) 직화구이 (소)
# 1  대구 북구 동북로 275 (우)41529           보통 돼지국밥 보통 내장국밥 수육 (소) 모듬순대 (소) 직화구이 (소)
# 2  대구 북구 동북로 275 (우)41529           보통 돼지국밥 보통 내장국밥 수육 (소) 모듬순대 (소) 직화구이 (소)
# 3  대구 북구 동북로 275 (우)41529           보통 돼지국밥 보통 내장국밥 수육 (소) 모듬순대 (소) 직화구이 (소)
# 4  대구 북구 동북로 275 (우)41529           보통 돼지국밥 보통 내장국밥 수육 (소) 모듬순대 (소) 직화구이 (소)
# 5  대구 북구 동북로 275 (우)41529           보통 돼지국밥 보통 내장국밥 수육 (소) 모듬순대 (소) 직화구이 (소)
# 6  대구 북구 동북로 275 (우)41529           보통 돼지국밥 보통 내장국밥 수육 (소) 모듬순대 (소) 직화구이 (소)
# 7  대구 북구 동북로 275 (우)41529           보통 돼지국밥 보통 내장국밥 수육 (소) 모듬순대 (소) 직화구이 (소)
#
#                                   카카오 url
# 4    https://place.map.kakao.com/34247199
# 5    https://place.map.kakao.com/34247199
# 0  https://place.map.kakao.com/1744813617
# 1  https://place.map.kakao.com/1744813617
# 2  https://place.map.kakao.com/1744813617
# 3  https://place.map.kakao.com/1744813617
# 4  https://place.map.kakao.com/1744813617
# 5  https://place.map.kakao.com/1744813617
# 6  https://place.map.kakao.com/1744813617
# 7  https://place.map.kakao.com/1744813617
# (202, 10)
#                                                    리뷰 별점 리뷰자 평균 평점  \
# 2   평점을 낮게 주신분들이 많아서 5점을 쓰면 댓글알바라고 의심은 하시겠지만,, 물비빔...  5       4.6
# 3                                          맛만좋은데 왜그러징  5       2.7
# 4   고기는 그냥 그래요! 직원 친절도는 완전꽥! 냉면도 별로...(겨자는 절대 넣지 마...  1       1.0
# 5                                      음....적당히 먹을만해요  3       3.2
# 6   청담면옥 수성구있는 맛에 반도못한듯 ... 그거기대하고 갔었는데 제대로 배우신거 맞...  3       3.1
# 7       밥이 억수로 맛나요.~~^갈비찜 육질도 괜찮고.담백하니 맛나네요.~^^잘먹었슴다.  5       5.0
# 8                         육수는 핑크색 냉면위에 육전은 기름기가 많고 질김  2       4.0
# 9                                 맛은 있어요 서빙분 친절은 별로예요  3       1.4
# 10                    육전 질기고 기름진 못먹을건아니지만 차라리 교동면옥이나음  2       2.7
# 11                                      왕갈비탕이 너무 맛있어요  5       5.0
#
#    리뷰자 누적 리뷰 개수             영업 시간  \
# 2            10  매일 11:00 ~ 23:00
# 3             7  매일 11:00 ~ 23:00
# 4             1  매일 11:00 ~ 23:00
# 5           158  매일 11:00 ~ 23:00
# 6             9  매일 11:00 ~ 23:00
# 7             1  매일 11:00 ~ 23:00
# 8            34  매일 11:00 ~ 23:00
# 9             5  매일 11:00 ~ 23:00
# 10            3  매일 11:00 ~ 23:00
# 11            1  매일 11:00 ~ 23:00
#
#                                                이미지url       가게명  \
# 2   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청담면옥 복현점
# 3   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청담면옥 복현점
# 4   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청담면옥 복현점
# 5   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청담면옥 복현점
# 6   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청담면옥 복현점
# 7   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청담면옥 복현점
# 8   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청담면옥 복현점
# 9   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청담면옥 복현점
# 10  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청담면옥 복현점
# 11  '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  청담면옥 복현점
#
#                      가게 주소                                              메뉴  \
# 2   대구 북구 동북로 281 (우)41529  육전 물냉면 육전비빔냉면 육전 물비면 한우 육회 냉면 특왕갈비탕 생갈비살(600g)
# 3   대구 북구 동북로 281 (우)41529  육전 물냉면 육전비빔냉면 육전 물비면 한우 육회 냉면 특왕갈비탕 생갈비살(600g)
# 4   대구 북구 동북로 281 (우)41529  육전 물냉면 육전비빔냉면 육전 물비면 한우 육회 냉면 특왕갈비탕 생갈비살(600g)
# 5   대구 북구 동북로 281 (우)41529  육전 물냉면 육전비빔냉면 육전 물비면 한우 육회 냉면 특왕갈비탕 생갈비살(600g)
# 6   대구 북구 동북로 281 (우)41529  육전 물냉면 육전비빔냉면 육전 물비면 한우 육회 냉면 특왕갈비탕 생갈비살(600g)
# 7   대구 북구 동북로 281 (우)41529  육전 물냉면 육전비빔냉면 육전 물비면 한우 육회 냉면 특왕갈비탕 생갈비살(600g)
# 8   대구 북구 동북로 281 (우)41529  육전 물냉면 육전비빔냉면 육전 물비면 한우 육회 냉면 특왕갈비탕 생갈비살(600g)
# 9   대구 북구 동북로 281 (우)41529  육전 물냉면 육전비빔냉면 육전 물비면 한우 육회 냉면 특왕갈비탕 생갈비살(600g)
# 10  대구 북구 동북로 281 (우)41529  육전 물냉면 육전비빔냉면 육전 물비면 한우 육회 냉면 특왕갈비탕 생갈비살(600g)
# 11  대구 북구 동북로 281 (우)41529  육전 물냉면 육전비빔냉면 육전 물비면 한우 육회 냉면 특왕갈비탕 생갈비살(600g)
#
#                                   카카오 url
# 2   https://place.map.kakao.com/593946204
# 3   https://place.map.kakao.com/593946204
# 4   https://place.map.kakao.com/593946204
# 5   https://place.map.kakao.com/593946204
# 6   https://place.map.kakao.com/593946204
# 7   https://place.map.kakao.com/593946204
# 8   https://place.map.kakao.com/593946204
# 9   https://place.map.kakao.com/593946204
# 10  https://place.map.kakao.com/593946204
# 11  https://place.map.kakao.com/593946204

# %%
total_df
# Out:
#                                                    리뷰 별점 리뷰자 평균 평점  \
# 0                                   성발라가 오히려 망친 것인가..  1       501
# 1   조용할 시간에 가서 너무 맛있게 편하게 먹었습니다. 서비스에 대해선 호불호가 있을 ...  5         5
# 2   왠만하면리뷰안쓰는데 최악중에최악 정말최악사장님이글보면 저아시겠죠? 서비스는바라지도않...  1         1
# 3   생고기 소자 주문하려니  양이 적다고  중자주문 유도한다 둘이 왔는데  중짜? 얼마...  1        22
# 4   성시경이 띄워놓았지만 대구에는 이것보다 훨씬 가성비 좋고 맛있는 생고기 집이 많다 ...  2        41
# ..                                                ... ..       ...
# 5                                    알바생 친절! 맛도 좋아요÷)  5        20
# 6                                    친절하고 사이드메뉴가 맛있어용  5        45
# 7                                                      3       424
# 8                                                      5        67
# 9                                                      5        98
#
#    리뷰자 누적 리뷰 개수             영업 시간  \
# 0           3.8  매일 17:00 ~ 24:00
# 1           3.4  매일 17:00 ~ 24:00
# 2           1.0  매일 17:00 ~ 24:00
# 3           3.5  매일 17:00 ~ 24:00
# 4           3.2  매일 17:00 ~ 24:00
# ..          ...               ...
# 5           4.0  매일 16:00 ~ 04:00
# 6           3.3  매일 16:00 ~ 04:00
# 7           4.0  매일 16:00 ~ 04:00
# 8           4.4  매일 16:00 ~ 04:00
# 9           4.0  매일 16:00 ~ 04:00
#
#                                                이미지url        가게명  \
# 0   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...   참조은생고기육회
# 1   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...   참조은생고기육회
# 2   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...   참조은생고기육회
# 3   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...   참조은생고기육회
# 4   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...   참조은생고기육회
# ..                                                ...        ...
# 5   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  우야지막창 복현점
# 6   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  우야지막창 복현점
# 7   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  우야지막창 복현점
# 8   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  우야지막창 복현점
# 9   '//t1.kakaocdn.net/thumb/T800x0.q80/?fname=htt...  우야지막창 복현점
#
#                        가게 주소
# 0   대구 북구 복현로 78 1층 (우)41528
# 1   대구 북구 복현로 78 1층 (우)41528
# 2   대구 북구 복현로 78 1층 (우)41528
# 3   대구 북구 복현로 78 1층 (우)41528
# 4   대구 북구 복현로 78 1층 (우)41528
# ..                       ...
# 5     대구 북구 경진로1길 9 (우)41562
# 6     대구 북구 경진로1길 9 (우)41562
# 7     대구 북구 경진로1길 9 (우)41562
# 8     대구 북구 경진로1길 9 (우)41562
# 9     대구 북구 경진로1길 9 (우)41562
#
# [215 rows x 8 columns]

# %%
total_df.to_csv('sample.csv')
