# %%
import pandas as pd
import numpy as np
import re
from konlpy.tag import Okt
from nltk import FreqDist
from tensorflow.keras.preprocessing.text import Tokenizer
from nltk.tokenize import TreebankWordTokenizer
from nltk import FreqDist
train = pd.read_csv('ratings_train (1).txt',sep='\t')
test = pd.read_csv('ratings_test.txt',sep='\t')

train
# Out:
#               id                                           document  label
# 0        9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1        3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...          ...                                                ...    ...
# 149995   6222902                                인간이 문제지.. 소는 뭔죄인가..      0
# 149996   8549745                                      평점이 너무 낮아서...      1
# 149997   9311800                    이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?      0
# 149998   2376369                        청춘 영화의 최고봉.방황과 우울했던 날들의 자화상      1
# 149999   9619869                           한국 영화 최초로 수간하는 내용이 담긴 영화      0
#
# [150000 rows x 3 columns]

# %% [markdown]
# # 1. 전처리

# %%
print('훈련용 리뷰 개수 :',len(train))
print('훈련용 리뷰 개수 :',len(test))
# Out:
# 훈련용 리뷰 개수 : 150000
# 훈련용 리뷰 개수 : 50000

# %% [markdown]
# # 1-1. null

# %%
train.isnull().sum()
test.isnull().sum()
# Out:
# id          0
# document    3
# label       0
# dtype: int64

# %%
train = train.dropna(subset=['document'])
test = test.dropna(subset=['document'])

# %%
train.isnull().sum()
test.isnull().sum()
# Out:
# id          0
# document    0
# label       0
# dtype: int64

# %% [markdown]
# # 2-1. 중복값

# %%
# document 열과 label 열의 중복을 제외한 값의 개수
train['document'].nunique(), train['label'].nunique()
test['document'].nunique(), test['label'].nunique()
# Out:
# (49157, 2)

# %%
train.drop_duplicates(subset=['document'], inplace=True)
test.drop_duplicates(subset=['document'], inplace=True)
# Out:
# C:\Users\jangmark\AppData\Local\Temp\ipykernel_2532\601824009.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.drop_duplicates(subset=['document'], inplace=True)

# %%
print('훈련용 리뷰 개수 :',len(train))
print('훈련용 리뷰 개수 :',len(test))
# Out:
# 훈련용 리뷰 개수 : 146182
# 훈련용 리뷰 개수 : 49157

# %% [markdown]
# # 1-3. 정규 표현식
#
# - [] : 대괄호 안에 문자들 중 한 개의 문자와 매치.
# - 한글 : [ㄱ-ㅎㅏ-ㅣ-가-힣],[가-힣]+ <- + : 앞의 문자가 최소 한 개 이상 존재합니다.
# - ^ : 뒤의 문자열로 문자열이 시작됩니다.
# - $ : 앞의 문자열로 문자열이 끝납니다.
# - [^문] : 해당 문자를 제외한 문자를 매치합니다.
#
# - 모듈 함수
#
# - re.compile() : 정규표현식을 컴파일하는 함수입니다.
# - re.findall() : 문자열에서 정규 표현식과 매치되는 모든 경우의 문자열을 찾아서 리스트로 리턴합니다. 만약, 매치되는 문자열이 없다면 빈 리스트가 리턴됩니다.
# - re.sub() : 문자열에서 정규 표현식과 일치하는 부분에 대해서 다른 문자열로 대체합니다.

# %%
# 정규표현식
pattern = re.compile("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]") # 한글을 제외한 모든 글자 뺌
# ["[^a-zA-Z]"] # 영어를 제외한 모든 글자 뺌

train['document'] = train['document'].apply(lambda x: pattern.sub('', x))
test['document'] = test['document'].apply(lambda x: pattern.sub('', x))

train = train.drop(['id'],axis=1)
test = test.drop(['id'],axis=1)
# Out:
# C:\Users\jangmark\AppData\Local\Temp\ipykernel_2532\3658156119.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['document'] = train['document'].apply(lambda x: pattern.sub('', x))

# %% [markdown]
# #  1-4. 불용어

# %%
stop_word = pd.read_csv('stopwords_kor.txt')

# %%
stop_word
# Out:
#     stop
# 0     않다
# 1    되어다
# 2     되다
# 3     하다
# 4    어떻다
# ..   ...
# 679   일곱
# 680   여덟
# 681   아홉
# 682    령
# 683    영
#
# [684 rows x 1 columns]

# %%
okt = Okt()

# %%
result = []
for sentence in train['document']:
    result.append(okt.nouns(sentence))

text = []
for word in result:
    if word not in stop_word['stop'].tolist():
        text.append(word)
text
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 3
#       1 result = []
#       2 for sentence in train['document']:
# ----> 3     result.append(okt.nouns(sentence))
#       5 text = []
#       6 for word in result:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\konlpy\tag\_okt.py:83, in Okt.nouns(self, phrase)
#      80 def nouns(self, phrase):
#      81     """Noun extractor."""
# ---> 83     tagged = self.pos(phrase)
#      84     return [s for s, t in tagged if t == 'Noun']
#
# File ~\AppData\Roaming\Python\Python38\site-packages\konlpy\tag\_okt.py:71, in Okt.pos(self, phrase, norm, stem, join)
#      59 """POS tagger.
#      60 In contrast to other classes in this subpackage,
#      61 this POS tagger doesn't have a `flatten` option,
#    (...)
#      67 :param join: If True, returns joined sets of morph and tag.
#      68 """
#      69 validate_phrase_inputs(phrase)
# ---> 71 tokens = self.jki.tokenize(
#      72             phrase,
#      73             jpype.java.lang.Boolean(norm),
#      74             jpype.java.lang.Boolean(stem)).toArray()
#      75 if join:
#      76     return [t for t in tokens]
#
# KeyboardInterrupt:

# %%
NUM_WORDS = 10000
OOV = 'OOV'

# %%
tokenizer = Tokenizer(num_words=NUM_WORDS, oov_token=OOV)

# fit_on_texts
tokenizer.fit_on_texts(text)

# %%
# 단어 인덱스 확인
word_index = tokenizer.word_index
word_index
# Out:
# {'OOV': 1,
#  '영화': 2,
#  '정말': 3,
#  '진짜': 4,
#  '이': 5,
#  '점': 6,
#  '것': 7,
#  '연기': 8,
#  '평점': 9,
#  '최고': 10,
#  '사람': 11,
#  '드라마': 12,
#  '스토리': 13,
#  '왜': 14,
#  '감동': 15,
#  '때': 16,
#  '보고': 17,
#  '생각': 18,
#  '말': 19,
#  '시간': 20,
#  '감독': 21,
#  '거': 22,
#  '배우': 23,
#  '내용': 24,
#  '그냥': 25,
#  '재미': 26,
#  '더': 27,
#  '내': 28,
#  '좀': 29,
#  '뭐': 30,
#  '쓰레기': 31,
#  '작품': 32,
#  '그': 33,
#  '사랑': 34,
#  '나': 35,
#  '주인공': 36,
#  '이건': 37,
#  '하나': 38,
#  '정도': 39,
#  '수': 40,
#  '돈': 41,
#  '볼': 42,
#  '액션': 43,
#  '마지막': 44,
#  '걸': 45,
#  '다시': 46,
#  '역시': 47,
#  '완전': 48,
#  '년': 49,
#  '느낌': 50,
#  '연출': 51,
#  '장면': 52,
#  '개': 53,
#  '이야기': 54,
#  '듯': 55,
#  '또': 56,
#  '최악': 57,
#  '임': 58,
#  '명작': 59,
#  '남자': 60,
#  '꼭': 61,
#  '인생': 62,
#  '지금': 63,
#  '별로': 64,
#  '처음': 65,
#  '안': 66,
#  '난': 67,
#  '기억': 68,
#  '알': 69,
#  '못': 70,
#  '이해': 71,
#  '소재': 72,
#  '이영화': 73,
#  '한번': 74,
#  '가슴': 75,
#  '끝': 76,
#  '매력': 77,
#  '현실': 78,
#  '분': 79,
#  '여자': 80,
#  '보기': 81,
#  '결말': 82,
#  '마음': 83,
#  '때문': 84,
#  '줄': 85,
#  '가장': 86,
#  '만': 87,
#  '애': 88,
#  '중': 89,
#  '수준': 90,
#  '함': 91,
#  '공감': 92,
#  '실망': 93,
#  '번': 94,
#  '움': 95,
#  '우리': 96,
#  '속': 97,
#  '자체': 98,
#  '무슨': 99,
#  '욕': 100,
#  '캐릭터': 101,
#  '저': 102,
#  '전개': 103,
#  '제목': 104,
#  '반전': 105,
#  '추천': 106,
#  '음악': 107,
#  '기분': 108,
#  '전혀': 109,
#  '표현': 110,
#  '인간': 111,
#  '코미디': 112,
#  '영상': 113,
#  '원작': 114,
#  '작가': 115,
#  '기대': 116,
#  '개봉': 117,
#  '뭔가': 118,
#  '별': 119,
#  '나름': 120,
#  '계속': 121,
#  '막장': 122,
#  '시리즈': 123,
#  '조금': 124,
#  '전': 125,
#  '연기력': 126,
#  '기': 127,
#  '눈물': 128,
#  '가족': 129,
#  '건': 130,
#  '대한': 131,
#  '눈': 132,
#  '요': 133,
#  '이유': 134,
#  '도': 135,
#  '몰입': 136,
#  '여운': 137,
#  '굿': 138,
#  '모든': 139,
#  '내내': 140,
#  '편': 141,
#  '절대': 142,
#  '일본': 143,
#  '노래': 144,
#  '아이': 145,
#  '게': 146,
#  '점도': 147,
#  '모습': 148,
#  '애니': 149,
#  '극장': 150,
#  '위': 151,
#  '대해': 152,
#  '한국': 153,
#  '요즘': 154,
#  '이상': 155,
#  '모두': 156,
#  '아주': 157,
#  '개인': 158,
#  '보지': 159,
#  '다른': 160,
#  '스릴러': 161,
#  '감': 162,
#  '캐스팅': 163,
#  '놈': 164,
#  '이제': 165,
#  '뭘': 166,
#  '대박': 167,
#  '문제': 168,
#  '당시': 169,
#  '자신': 170,
#  '용': 171,
#  '알바': 172,
#  '뿐': 173,
#  '부분': 174,
#  '긴장감': 175,
#  '웃음': 176,
#  '티비': 177,
#  '전쟁': 178,
#  '시나리오': 179,
#  '삶': 180,
#  '년대': 181,
#  '제일': 182,
#  '우리나라': 183,
#  '진심': 184,
#  '후': 185,
#  '추억': 186,
#  '친구': 187,
#  '이후': 188,
#  '정신': 189,
#  '초반': 190,
#  '인상': 191,
#  '잼': 192,
#  '한마디': 193,
#  '배경': 194,
#  '물': 195,
#  '최고다': 196,
#  '의미': 197,
#  '맘': 198,
#  '중간': 199,
#  '일': 200,
#  '건가': 201,
#  '도대체': 202,
#  '로': 203,
#  '급': 204,
#  '앞': 205,
#  '세상': 206,
#  '장난': 207,
#  '점수': 208,
#  '공포': 209,
#  '포스터': 210,
#  '코': 211,
#  '수작': 212,
#  '몰입도': 213,
#  '한국영': 214,
#  '설정': 215,
#  '나이': 216,
#  '오늘': 217,
#  '라면': 218,
#  '공포영화': 219,
#  '접': 220,
#  '제대로': 221,
#  '데': 222,
#  '그대로': 223,
#  '감정': 224,
#  '회': 225,
#  '로맨스': 226,
#  '해': 227,
#  '대사': 228,
#  '엄마': 229,
#  '책': 230,
#  '중국': 231,
#  '차라리': 232,
#  '해도': 233,
#  '갈수록': 234,
#  '졸작': 235,
#  '등': 236,
#  '남': 237,
#  '가지': 238,
#  '여기': 239,
#  '얼굴': 240,
#  '자기': 241,
#  '실화': 242,
#  '팬': 243,
#  '무엇': 244,
#  '머': 245,
#  '기도': 246,
#  '제발': 247,
#  '소리': 248,
#  '영화관': 249,
#  '분위기': 250,
#  '꽤': 251,
#  '뻔': 252,
#  '관객': 253,
#  '시청률': 254,
#  '순간': 255,
#  '구성': 256,
#  '시대': 257,
#  '봄': 258,
#  '영화인': 259,
#  '장르': 260,
#  '출연': 261,
#  '좀비': 262,
#  '노잼': 263,
#  '자': 264,
#  '집': 265,
#  '질': 266,
#  '류': 267,
#  '후회': 268,
#  '년도': 269,
#  '날': 270,
#  '여배우': 271,
#  '진': 272,
#  '키': 273,
#  '씬': 274,
#  '제': 275,
#  '소름': 276,
#  '맛': 277,
#  '짜증': 278,
#  '다큐': 279,
#  '산': 280,
#  '흥행': 281,
#  '킬링타임': 282,
#  '미국': 283,
#  '답': 284,
#  '피': 285,
#  '웃기': 286,
#  '비': 287,
#  '음': 288,
#  '극장판': 289,
#  '역사': 290,
#  '당신': 291,
#  '질질': 292,
#  '얘기': 293,
#  '사실': 294,
#  '만화': 295,
#  '존나': 296,
#  '전체': 297,
#  '를': 298,
#  '간만': 299,
#  '예술': 300,
#  '시즌': 301,
#  '초딩': 302,
#  '의': 303,
#  '감성': 304,
#  '뒤': 305,
#  '낭비': 306,
#  '충격': 307,
#  '위해': 308,
#  '노력': 309,
#  '어디': 310,
#  '상황': 311,
#  '옛날': 312,
#  '네이버': 313,
#  '코믹': 314,
#  '화보': 315,
#  '평생': 316,
#  '전작': 317,
#  '머리': 318,
#  '막': 319,
#  '짱': 320,
#  '손': 321,
#  '대체': 322,
#  '터': 323,
#  '언제': 324,
#  '매우': 325,
#  '시작': 326,
#  '점점': 327,
#  '또한': 328,
#  '재밋': 329,
#  '화가': 330,
#  '판': 331,
#  '보': 332,
#  '꿈': 333,
#  '시절': 334,
#  '작': 335,
#  '스릴': 336,
#  '개연': 337,
#  '영화로': 338,
#  '누가': 339,
#  '다운': 340,
#  '엔딩': 341,
#  '참고': 342,
#  '소녀': 343,
#  '은': 344,
#  '무조건': 345,
#  '니': 346,
#  '반개': 347,
#  '발연기': 348,
#  '엉망': 349,
#  '성룡': 350,
#  '전부': 351,
#  '아들': 352,
#  '년전': 353,
#  '살': 354,
#  '한편': 355,
#  '화이팅': 356,
#  '얼마나': 357,
#  '두': 358,
#  '세계': 359,
#  '흥미진진': 360,
#  '사회': 361,
#  '사건': 362,
#  '곳': 363,
#  '존재': 364,
#  '만점': 365,
#  '여주': 366,
#  '게이': 367,
#  '화면': 368,
#  '원래': 369,
#  '몸': 370,
#  '더빙': 371,
#  '발': 372,
#  '몇': 373,
#  '노': 374,
#  '명': 375,
#  '평가': 376,
#  '가면': 377,
#  '가요': 378,
#  '특유': 379,
#  '케이블': 380,
#  '방송': 381,
#  '그녀': 382,
#  '게임': 383,
#  '일단': 384,
#  '귀신': 385,
#  '너': 386,
#  '느와르': 387,
#  '부': 388,
#  '드': 389,
#  '지루함': 390,
#  '비디오': 391,
#  '준': 392,
#  '아빠': 393,
#  '애니메이션': 394,
#  '실제': 395,
#  '똥': 396,
#  '그래픽': 397,
#  '갑자기': 398,
#  '복수': 399,
#  '상영': 400,
#  '미화': 401,
#  '아저씨': 402,
#  '통해': 403,
#  '걸작': 404,
#  '프랑스': 405,
#  '평': 406,
#  '여': 407,
#  '꿀잼': 408,
#  '기적': 409,
#  '주연': 410,
#  '심리': 411,
#  '거의': 412,
#  '흠': 413,
#  '세': 414,
#  '주제': 415,
#  '안나': 416,
#  '간다': 417,
#  '소설': 418,
#  '살인': 419,
#  '강추': 420,
#  '끌': 421,
#  '실감': 422,
#  '교훈': 423,
#  '면': 424,
#  '어린이': 425,
#  '완성': 426,
#  '예산': 427,
#  '생': 428,
#  '액션영화': 429,
#  '범죄': 430,
#  '편이': 431,
#  '거기': 432,
#  '구': 433,
#  '스타': 434,
#  '티': 435,
#  '수가': 436,
#  '요소': 437,
#  '시도': 438,
#  '상미': 439,
#  '선택': 440,
#  '강': 441,
#  '역대': 442,
#  '촬영': 443,
#  '비교': 444,
#  '죄': 445,
#  '스파이더맨': 446,
#  '반복': 447,
#  '취향': 448,
#  '이기': 449,
#  '중반': 450,
#  '혼자': 451,
#  '악역': 452,
#  '깊이': 453,
#  '바로': 454,
#  '차': 455,
#  '빨': 456,
#  '진정': 457,
#  '유': 458,
#  '술': 459,
#  '흥미': 460,
#  '퀄리티': 461,
#  '적': 462,
#  '죽': 463,
#  '청춘': 464,
#  '댓글': 465,
#  '이름': 466,
#  '굳이': 467,
#  '대작': 468,
#  '둘': 469,
#  '아픔': 470,
#  '약간': 471,
#  '다음': 472,
#  '속편': 473,
#  '이하': 474,
#  '희망': 475,
#  '관람': 476,
#  '제작': 477,
#  '동시': 478,
#  '누구': 479,
#  '집중': 480,
#  '만하': 481,
#  '아버지': 482,
#  '선': 483,
#  '총': 484,
#  '울': 485,
#  '현재': 486,
#  '편집': 487,
#  '아쉬움': 488,
#  '과정': 489,
#  '형': 490,
#  '단': 491,
#  '몇번': 492,
#  '형제': 493,
#  '과거': 494,
#  '목소리': 495,
#  '그것': 496,
#  '볼때': 497,
#  '멜로': 498,
#  '도안': 499,
#  '방법': 500,
#  '동화': 501,
#  '말로': 502,
#  '예전': 503,
#  '외국': 504,
#  '사극': 505,
#  '판타지': 506,
#  '시': 507,
#  '가치': 508,
#  '연인': 509,
#  '땐': 510,
#  '진행': 511,
#  '의도': 512,
#  '이번': 513,
#  '관': 514,
#  '벌써': 515,
#  '최근': 516,
#  '점주': 517,
#  '그게': 518,
#  '홍보': 519,
#  '각본': 520,
#  '새끼': 521,
#  '동안': 522,
#  '배': 523,
#  '이면': 524,
#  '포기': 525,
#  '달': 526,
#  '긴장': 527,
#  '표절': 528,
#  '수도': 529,
#  '온': 530,
#  '에피소드': 531,
#  '불륜': 532,
#  '자극': 533,
#  '잠': 534,
#  '초': 535,
#  '필요': 536,
#  '그때': 537,
#  '조연': 538,
#  '프로': 539,
#  '괴물': 540,
#  '역': 541,
#  '묘사': 542,
#  '딸': 543,
#  '세기': 544,
#  '누군가': 545,
#  '연예인': 546,
#  '조폭': 547,
#  '진리': 548,
#  '제작비': 549,
#  '인물': 550,
#  '리얼': 551,
#  '망작': 552,
#  '평론가': 553,
#  '스': 554,
#  '자식': 555,
#  '주기': 556,
#  '억지': 557,
#  '올해': 558,
#  '남녀': 559,
#  '무': 560,
#  '쵝오': 561,
#  '길': 562,
#  '삼류': 563,
#  '젠': 564,
#  '아줌마': 565,
#  '명화': 566,
#  '종교': 567,
#  '짓': 568,
#  '린다': 569,
#  '다행': 570,
#  '처럼': 571,
#  '용도': 572,
#  '끼리': 573,
#  '등장': 574,
#  '쓰래': 575,
#  '미드': 576,
#  '아침': 577,
#  '첨': 578,
#  '씨': 579,
#  '예고편': 580,
#  '따위': 581,
#  '개판': 582,
#  '거지': 583,
#  '낫다': 584,
#  '손발': 585,
#  '먼저': 586,
#  '안보': 587,
#  '정': 588,
#  '등장인물': 589,
#  '스타일': 590,
#  '재': 591,
#  '어이': 592,
#  '미션임파서블': 593,
#  '학교': 594,
#  '잘만': 595,
#  '그림': 596,
#  '어른': 597,
#  '우정': 598,
#  '전편': 599,
#  '비판': 600,
#  '몇몇': 601,
#  '힘': 602,
#  '표정': 603,
#  '학년': 604,
#  '열정': 605,
#  '탈': 606,
#  '바': 607,
#  '상태': 608,
#  '불가': 609,
#  '북한': 610,
#  '용이': 611,
#  '쫌': 612,
#  '왕': 613,
#  '연기자': 614,
#  '나라': 615,
#  '살짝': 616,
#  '고민': 617,
#  '상상': 618,
#  '조절': 619,
#  '실력': 620,
#  '면서': 621,
#  '제로': 622,
#  '대가': 623,
#  '란': 624,
#  '부터': 625,
#  '전달': 626,
#  '월': 627,
#  '슬픔': 628,
#  '천재': 629,
#  '신분': 630,
#  '랄': 631,
#  '대한민국': 632,
#  '동영상': 633,
#  '메세지': 634,
#  '레전드': 635,
#  '서로': 636,
#  '거리': 637,
#  '공부': 638,
#  '선생님': 639,
#  '기술': 640,
#  '자막': 641,
#  '문화': 642,
#  '잘못': 643,
#  '개뿔': 644,
#  '행동': 645,
#  '다만': 646,
#  '장가': 647,
#  '카메라': 648,
#  '철학': 649,
#  '죽음': 650,
#  '자연': 651,
#  '청소년': 652,
#  '타임': 653,
#  '만화책': 654,
#  '설득': 655,
#  '무협': 656,
#  '이란': 657,
#  '미학': 658,
#  '줌': 659,
#  '혹시': 660,
#  '후속작': 661,
#  '국가': 662,
#  '기세': 663,
#  '줄거리': 664,
#  '평이': 665,
#  '땅': 666,
#  '심': 667,
#  '예능': 668,
#  '더욱': 669,
#  '하이': 670,
#  '틴': 671,
#  '전설': 672,
#  '성장': 673,
#  '프로그램': 674,
#  '영환': 675,
#  '무지': 676,
#  '성우': 677,
#  '환상': 678,
#  '도저히': 679,
#  '만큼': 680,
#  '햇': 681,
#  '발전': 682,
#  '마무리': 683,
#  '밑': 684,
#  '항상': 685,
#  '글': 686,
#  '고생': 687,
#  '과연': 688,
#  '마': 689,
#  '초등학교': 690,
#  '네': 691,
#  '절제': 692,
#  '는걸': 693,
#  '발견': 694,
#  '미소': 695,
#  '기본': 696,
#  '잠시': 697,
#  '일상': 698,
#  '이정': 699,
#  '코드': 700,
#  '분만': 701,
#  '별루': 702,
#  '지난': 703,
#  '배역': 704,
#  '쪽': 705,
#  '후반': 706,
#  '일품': 707,
#  '역할': 708,
#  '로써': 709,
#  '시종일관': 710,
#  '기존': 711,
#  '신': 712,
#  '하라': 713,
#  '짜임새': 714,
#  '안습': 715,
#  '아역': 716,
#  '과': 717,
#  '탑': 718,
#  '역작': 719,
#  '나중': 720,
#  '견자단': 721,
#  '아누': 722,
#  '다소': 723,
#  '밥': 724,
#  '그린': 725,
#  '일이': 726,
#  '군대': 727,
#  '하늘': 728,
#  '쩌': 729,
#  '성격': 730,
#  '종영': 731,
#  '매니아': 732,
#  '대안': 733,
#  '쩐다': 734,
#  '바람': 735,
#  '일찍': 736,
#  '가끔': 737,
#  '유머': 738,
#  '형님': 739,
#  '불': 740,
#  '패러디': 741,
#  '신경': 742,
#  '유럽': 743,
#  '깨': 744,
#  '설명': 745,
#  '한계': 746,
#  '상처': 747,
#  '덕분': 748,
#  '형편': 749,
#  '데리': 750,
#  '화란': 751,
#  '쉬': 752,
#  '여성': 753,
#  '시점': 754,
#  '정작': 755,
#  '관심': 756,
#  '도전': 757,
#  '방': 758,
#  '옆': 759,
#  '영화감독': 760,
#  '앞뒤': 761,
#  '채널': 762,
#  '폭력': 763,
#  '정서': 764,
#  '주성치': 765,
#  '지구': 766,
#  '개념': 767,
#  '순': 768,
#  '연결': 769,
#  '신의': 770,
#  '지상파': 771,
#  '내면': 772,
#  '본적': 773,
#  '스케일': 774,
#  '중학교': 775,
#  '마을': 776,
#  '감상': 777,
#  '허세': 778,
#  '운': 779,
#  '아': 780,
#  '보라': 781,
#  '꼴': 782,
#  '외': 783,
#  '이연걸': 784,
#  '굿굿': 785,
#  '심장': 786,
#  '좀더': 787,
#  '게다가': 788,
#  '고': 789,
#  '호러': 790,
#  '관점': 791,
#  '트': 792,
#  '감탄': 793,
#  '만족': 794,
#  '망': 795,
#  '별개': 796,
#  '낚': 797,
#  '흐름': 798,
#  '동물': 799,
#  '방금': 800,
#  '영': 801,
#  '오버': 802,
#  '무재': 803,
#  '어거지': 804,
#  '학생': 805,
#  '납득': 806,
#  '꽃': 807,
#  '마이너스': 808,
#  '월드': 809,
#  '푹': 810,
#  '카리스마': 811,
#  '당황': 812,
#  '은희': 813,
#  '컷': 814,
#  '조작': 815,
#  '아무나': 816,
#  '갈등': 817,
#  '단연': 818,
#  '진창': 819,
#  '우뢰매': 820,
#  '투': 821,
#  '뭥미': 822,
#  '생애': 823,
#  '공짜': 824,
#  '상대': 825,
#  '보아': 826,
#  '젤': 827,
#  '만해': 828,
#  '감히': 829,
#  '하나로': 830,
#  '혹': 831,
#  '조합': 832,
#  '김': 833,
#  '성': 834,
#  '춤': 835,
#  '어제': 836,
#  '주기도': 837,
#  '돼지': 838,
#  '어': 839,
#  '어린시절': 840,
#  '지옥': 841,
#  '무한': 842,
#  '결정': 843,
#  '새벽': 844,
#  '낼': 845,
#  '모순': 846,
#  '짱짱': 847,
#  '본인': 848,
#  '피해자': 849,
#  '필름': 850,
#  '이구': 851,
#  '쇼': 852,
#  '어색': 853,
#  '호구': 854,
#  '장': 855,
#  '암': 856,
#  '법': 857,
#  '핵': 858,
#  '개그': 859,
#  '히어로': 860,
#  '극': 861,
#  '중심': 862,
#  '펑펑': 863,
#  '도움': 864,
#  '영활': 865,
#  '변태': 866,
#  '깜짝': 867,
#  '쥐': 868,
#  '땜': 869,
#  '주변': 870,
#  '보이': 871,
#  '로버트': 872,
#  '전반': 873,
#  '사고': 874,
#  '았': 875,
#  '성은': 876,
#  '관계': 877,
#  '타': 878,
#  '응원': 879,
#  '노출': 880,
#  '만들기': 881,
#  '몸매': 882,
#  '유치': 883,
#  '나와라': 884,
#  '영웅': 885,
#  '양심': 886,
#  '무어': 887,
#  '무비': 888,
#  '여인': 889,
#  '첫': 890,
#  '던데': 891,
#  '남성': 892,
#  '주윤발': 893,
#  '동생': 894,
#  '절대로': 895,
#  '뇌': 896,
#  '여러가지': 897,
#  '아기': 898,
#  '빛': 899,
#  '링': 900,
#  '크게': 901,
#  '독립영화': 902,
#  '인지': 903,
#  '시청자': 904,
#  '걱정': 905,
#  '팔': 906,
#  '로서': 907,
#  '자주': 908,
#  '짐': 909,
#  '보신': 910,
#  '특수': 911,
#  '효과': 912,
#  '로그인': 913,
#  '노인': 914,
#  '블록버스터': 915,
#  '왕자': 916,
#  '일부러': 917,
#  '때매': 918,
#  '나머지': 919,
#  '번은': 920,
#  '존경': 921,
#  '한참': 922,
#  '연관': 923,
#  '멋': 924,
#  '결혼': 925,
#  '임권택': 926,
#  '그닥': 927,
#  '풀': 928,
#  '향연': 929,
#  '악': 930,
#  '원': 931,
#  '꽝': 932,
#  '볼거리': 933,
#  '커플': 934,
#  '노답': 935,
#  '톰': 936,
#  '리메이크': 937,
#  '미래': 938,
#  '수고': 939,
#  '예상': 940,
#  '호흡': 941,
#  '유리': 942,
#  '반': 943,
#  '앞서': 944,
#  '본성': 945,
#  '무료': 946,
#  '초등학생': 947,
#  '젠장': 948,
#  '압권': 949,
#  '해피엔딩': 950,
#  '오브': 951,
#  '외화': 952,
#  '형사': 953,
#  '늘': 954,
#  '나소': 955,
#  '공간': 956,
#  '기회': 957,
#  '무시': 958,
#  '구나': 959,
#  '추리': 960,
#  '졸라': 961,
#  '얼': 962,
#  '부족': 963,
#  '섹스': 964,
#  '꼬': 965,
#  '오': 966,
#  '존': 967,
#  '억지로': 968,
#  '앤': 969,
#  '홍콩': 970,
#  '예수': 971,
#  '코난': 972,
#  '생활': 973,
#  '헐리우드': 974,
#  '향수': 975,
#  '달인': 976,
#  '울면': 977,
#  '로만': 978,
#  '매번': 979,
#  '뜻': 980,
#  '음식': 981,
#  '차이': 982,
#  '풍경': 983,
#  '고추': 984,
#  '검사': 985,
#  '리얼리티': 986,
#  '이민기': 987,
#  '콩': 988,
#  '예측': 989,
#  '극적': 990,
#  '현대': 991,
#  '학살': 992,
#  '살인자': 993,
#  '부작': 994,
#  '불구': 995,
#  '러시아': 996,
#  '사진': 997,
#  '내일': 998,
#  '광고': 999,
#  '행복': 1000,
#  ...}

# %%
# 숫자로 변환
rets = tokenizer.texts_to_sequences(text)

# %%
length = [len(x) for x in rets]
Token_Length = max(length)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

rets2 = pad_sequences(rets,maxlen=Token_Length, padding='post', truncating='post')
rets2
# Out:
# array([[ 371,    4,  495, ...,    0,    0,    0],
#        [ 413,  210,   17, ...,    0,    0,    0],
#        [ 803, 2810, 1283, ...,    0,    0,    0],
#        ...,
#        [6779, 1236,   36, ...,    0,    0,    0],
#        [6780, 6781, 6782, ...,    0,    0,    0],
#        [ 102,  556,   95, ...,    0,    0,    0]])

# %%
# 모델에 적용
from tensorflow.keras.models import Sequential
model = Sequential()

# %%
from tensorflow.keras.layers import SimpleRNN
model.add(input_shape=(3,5))
model.add(SimpleRNN())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 from tensorflow.keras.layers import SimpleRNN
# ----> 2 model.add(input_shape=(3,5))
#       3 model.add(SimpleRNN())
#
# File ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\trackable\base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~\AppData\Roaming\Python\Python38\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Roaming\Python\Python38\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# TypeError: add() got an unexpected keyword argument 'input_shape'

# %%
word_index = len(tokenizer.word_index)
word_index
# Out:
# 6791

# %%
from tensorflow.keras.layers import  Embedding
model.add(Embedding(word_index+1,     2,       input_length=5))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 5, 2)              13584
#
# =================================================================
# Total params: 13,584
# Trainable params: 13,584
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse')
